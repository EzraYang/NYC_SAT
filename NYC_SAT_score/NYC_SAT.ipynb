# %%
import pandas as pd
import numpy as np

files = ["ap_2010.csv", "class_size.csv", 
         "demographics.csv", "graduation.csv", 
         "hs_directory.csv", "math_test_results.csv", 
         "sat_results.csv"]

data = {}

# 把所有df放到一个dict里
for f in files:
    d = pd.read_csv("schools/{0}".format(f))
    data[f.replace(".csv", "")] = d

# %%
data.keys()
# Out:
# dict_keys(['hs_directory', 'math_test_results', 'graduation', 'sat_results', 'ap_2010', 'class_size', 'demographics'])

# %%
for key, val in data.items():
    print('--'* 30 + '\n' + key + '：\n')
    print(val.head(2))
# Out:
# ------------------------------------------------------------
# hs_directory：
#
#       dbn                          school_name      boro building_code  \
# 0  17K548  Brooklyn School for Music & Theatre  Brooklyn          K440
# 1  09X543     High School for Violin and Dance     Bronx          X400
#
#    phone_number    fax_number grade_span_min  grade_span_max  \
# 0  718-230-6250  718-230-6262              9              12
# 1  718-842-0687  718-589-9849              9              12
#
#   expgrade_span_min  expgrade_span_max  \
# 0               NaN                NaN
# 1               NaN                NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
#
#                                           priority02  \
# 0                    Then to New York City residents
# 1  Then to New York City residents who attend an ...
#
#                             priority03                       priority04  \
# 0                                  NaN                              NaN
# 1  Then to Bronx students or residents  Then to New York City residents
#
#   priority05 priority06  priority07 priority08  priority09 priority10  \
# 0        NaN        NaN         NaN        NaN         NaN        NaN
# 1        NaN        NaN         NaN        NaN         NaN        NaN
#
#                                           Location 1
# 0  883 Classon Avenue\nBrooklyn, NY 11225\n(40.67...
# 1  1110 Boston Road\nBronx, NY 10456\n(40.8276026...
#
# [2 rows x 58 columns]
# ------------------------------------------------------------
# math_test_results：
#
#       DBN Grade  Year      Category  Number Tested Mean Scale Score Level 1 #  \
# 0  01M015     3  2006  All Students             39              667         2
# 1  01M015     3  2007  All Students             31              672         2
#
#   Level 1 % Level 2 # Level 2 % Level 3 # Level 3 % Level 4 # Level 4 %  \
# 0      5.1%        11     28.2%        20     51.3%         6     15.4%
# 1      6.5%         3      9.7%        22       71%         4     12.9%
#
#   Level 3+4 # Level 3+4 %
# 0          26       66.7%
# 1          26       83.9%
# ------------------------------------------------------------
# graduation：
#
#     Demographic     DBN                            School Name Cohort  \
# 0  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2003
# 1  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2004
#
#    Total Cohort Total Grads - n Total Grads - % of cohort Total Regents - n  \
# 0             5               s                         s                 s
# 1            55              37                     67.3%                17
#
#   Total Regents - % of cohort Total Regents - % of grads  \
# 0                           s                          s
# 1                       30.9%                      45.9%
#
#              ...            Regents w/o Advanced - n  \
# 0            ...                                   s
# 1            ...                                  17
#
#   Regents w/o Advanced - % of cohort Regents w/o Advanced - % of grads  \
# 0                                  s                                 s
# 1                              30.9%                             45.9%
#
#   Local - n Local - % of cohort Local - % of grads Still Enrolled - n  \
# 0         s                   s                  s                  s
# 1        20               36.4%              54.1%                 15
#
#   Still Enrolled - % of cohort Dropped Out - n Dropped Out - % of cohort
# 0                            s               s                         s
# 1                        27.3%               3                      5.5%
#
# [2 rows x 23 columns]
# ------------------------------------------------------------
# sat_results：
#
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
#
#   SAT Writing Avg. Score
# 0                    363
# 1                    366
# ------------------------------------------------------------
# ap_2010：
#
#       DBN                    SchoolName AP Test Takers  Total Exams Taken  \
# 0  01M448  UNIVERSITY NEIGHBORHOOD H.S.              39                49
# 1  01M450        EAST SIDE COMMUNITY HS              19                21
#
#   Number of Exams with scores 3 4 or 5
# 0                                   10
# 1                                    s
# ------------------------------------------------------------
# class_size：
#
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# 1    1       M        M015  P.S. 015 Roberto Clemente     0K          CTT
#
#   CORE SUBJECT (MS CORE and 9-12 ONLY) CORE COURSE (MS CORE and 9-12 ONLY)  \
# 0                                    -                                   -
# 1                                    -                                   -
#
#   SERVICE CATEGORY(K-9* ONLY)  NUMBER OF STUDENTS / SEATS FILLED  \
# 0                           -                               19.0
# 1                           -                               21.0
#
#    NUMBER OF SECTIONS  AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  \
# 0                 1.0                19.0                    19.0
# 1                 1.0                21.0                    21.0
#
#    SIZE OF LARGEST CLASS DATA SOURCE  SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                   19.0         ATS                             NaN
# 1                   21.0         ATS                             NaN
# ------------------------------------------------------------
# demographics：
#
#       DBN                       Name  schoolyear fl_percent  frl_percent  \
# 0  01M015  P.S. 015 ROBERTO CLEMENTE    20052006       89.4          NaN
# 1  01M015  P.S. 015 ROBERTO CLEMENTE    20062007       89.4          NaN
#
#    total_enrollment prek   k grade1 grade2    ...     black_num black_per  \
# 0               281   15  36     40     33    ...            74      26.3
# 1               243   15  29     39     38    ...            68      28.0
#
#   hispanic_num hispanic_per white_num white_per male_num male_per female_num  \
# 0          189         67.3         5       1.8    158.0     56.2      123.0
# 1          153         63.0         4       1.6    140.0     57.6      103.0
#
#   female_per
# 0       43.8
# 1       42.4
#
# [2 rows x 38 columns]

# %% [markdown]
# 观察看到除了class_size和hs_directory，每个表里都有一栏‘DBN’，谷歌一下知道这是学校的unique code。这可能是把所有表merge的一个关键词。

# %%
data['class_size'].head()
# Out:
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# 1    1       M        M015  P.S. 015 Roberto Clemente     0K          CTT
# 2    1       M        M015  P.S. 015 Roberto Clemente     01       GEN ED
# 3    1       M        M015  P.S. 015 Roberto Clemente     01          CTT
# 4    1       M        M015  P.S. 015 Roberto Clemente     02       GEN ED
#
#   CORE SUBJECT (MS CORE and 9-12 ONLY) CORE COURSE (MS CORE and 9-12 ONLY)  \
# 0                                    -                                   -
# 1                                    -                                   -
# 2                                    -                                   -
# 3                                    -                                   -
# 4                                    -                                   -
#
#   SERVICE CATEGORY(K-9* ONLY)  NUMBER OF STUDENTS / SEATS FILLED  \
# 0                           -                               19.0
# 1                           -                               21.0
# 2                           -                               17.0
# 3                           -                               17.0
# 4                           -                               15.0
#
#    NUMBER OF SECTIONS  AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  \
# 0                 1.0                19.0                    19.0
# 1                 1.0                21.0                    21.0
# 2                 1.0                17.0                    17.0
# 3                 1.0                17.0                    17.0
# 4                 1.0                15.0                    15.0
#
#    SIZE OF LARGEST CLASS DATA SOURCE  SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                   19.0         ATS                             NaN
# 1                   21.0         ATS                             NaN
# 2                   17.0         ATS                             NaN
# 3                   17.0         ATS                             NaN
# 4                   15.0         ATS                             NaN

# %%
# 给class_size和hs_directory两个表加上‘DBN'一栏
data["class_size"]["DBN"] = data["class_size"].apply(lambda x: "{0:02d}{1}".format(x["CSD"], x["SCHOOL CODE"]), axis=1)
data["hs_directory"]["DBN"] = data["hs_directory"]["dbn"]

# %% [markdown]
# 中途发现了其它有用数据，加上

# %%
survey1 = pd.read_excel(open('schools/survey_all.xlsx', 'rb'), 
                        sheetname = 'Sheet1', 
                        skiprows = [0, 1])
survey2 = pd.read_excel(open('schools/survey_d75.xlsx', 'rb'), 
                        sheetname = 'Sheet1', 
                        skiprows = [0, 1])

survey1['d75'] = False
survey2['d75'] = True
survey = pd.concat([survey1, survey2], axis=0)

# %%
print(len(survey1.columns), len(survey2.columns))
# Out:
# 1938 1769

# %%
survey.head()
# Out:
#      N_p    N_s   N_t  aca_p_11  aca_s_11  aca_t_11  aca_tot_11  com_p_11  \
# 0   90.0    NaN  22.0       7.8       NaN       7.9         7.9       7.6
# 1  161.0    NaN  34.0       7.8       NaN       9.1         8.4       7.6
# 2  367.0    NaN  42.0       8.6       NaN       7.5         8.0       8.3
# 3  151.0  145.0  29.0       8.5       7.4       7.8         7.9       8.2
# 4   90.0    NaN  23.0       7.9       NaN       8.1         8.0       7.9
#
#    com_s_11  com_t_11   ...    t_q8c_1 t_q8c_2 t_q8c_3  t_q8c_4  t_q9  t_q9_1  \
# 0       NaN       7.8   ...       29.0    67.0     5.0      0.0   NaN     5.0
# 1       NaN       8.5   ...       74.0    21.0     6.0      0.0   NaN     3.0
# 2       NaN       6.3   ...       33.0    35.0    20.0     13.0   NaN     3.0
# 3       5.9       6.2   ...       21.0    45.0    28.0      7.0   NaN     0.0
# 4       NaN       7.3   ...       59.0    36.0     5.0      0.0   NaN    10.0
#
#    t_q9_2  t_q9_3  t_q9_4  t_q9_5
# 0    14.0    52.0    24.0     5.0
# 1     6.0     3.0    78.0     9.0
# 2     5.0    16.0    70.0     5.0
# 3    18.0    32.0    39.0    11.0
# 4     5.0    10.0    60.0    15.0
#
# [5 rows x 2769 columns]

# %%
# 初步清洗一下survey, 加到data dictionary里
survey["DBN"] = survey["dbn"]

survey_fields = ["DBN", 
                 "rr_s", "rr_t", "rr_p", 
                 "N_s", "N_t", "N_p", 
                 "saf_p_11", "com_p_11", "eng_p_11", "aca_p_11", 
                 "saf_t_11", "com_t_11", "eng_t_10", "aca_t_11", 
                 "saf_s_11", "com_s_11", "eng_s_11", "aca_s_11", 
                 "saf_tot_11", "com_tot_11", "eng_tot_11", "aca_tot_11"
                ]
survey = survey.loc[:,survey_fields]
data["survey"] = survey
survey.shape
# Out:
# (1702, 23)

# %% [markdown]
# 现在data dictionary里有7个dataframe，每个dataframe里都有一栏代表学校代码的'DBN'。

# %% [markdown]
# ## condensing dataset

# %% [markdown]
# 如果以'DBN'为关键词来合并所有dataframe，需要确保每个'DBN'只有一行。

# %%
for key in data.keys():
    print(key)
    print(len(data[key]['DBN']) - len(data[key]['DBN'].unique()))
# Out:
# hs_directory
# 0
# survey
# 0
# math_test_results
# 27346
# graduation
# 24673
# sat_results
# 0
# ap_2010
# 1
# class_size
# 26124
# demographics
# 8481

# %% [markdown]
# 可以看到在'math_test_results', 'graduation', 'ap_2010', 'class_size'和'demographcis'里至少一个DBN出现了多次。我们需要对这五个表操作一下把多行aggregate为一行。

# %% [markdown]
# ### clean math_test_results

# %%
math = data['math_test_results']
math.head()
# Out:
#       DBN Grade  Year      Category  Number Tested Mean Scale Score Level 1 #  \
# 0  01M015     3  2006  All Students             39              667         2
# 1  01M015     3  2007  All Students             31              672         2
# 2  01M015     3  2008  All Students             37              668         0
# 3  01M015     3  2009  All Students             33              668         0
# 4  01M015     3  2010  All Students             26              677         6
#
#   Level 1 % Level 2 # Level 2 % Level 3 # Level 3 % Level 4 # Level 4 %  \
# 0      5.1%        11     28.2%        20     51.3%         6     15.4%
# 1      6.5%         3      9.7%        22       71%         4     12.9%
# 2        0%         6     16.2%        29     78.4%         2      5.4%
# 3        0%         4     12.1%        28     84.8%         1        3%
# 4     23.1%        12     46.2%         6     23.1%         2      7.7%
#
#   Level 3+4 # Level 3+4 %
# 0          26       66.7%
# 1          26       83.9%
# 2          31       83.8%
# 3          29       87.9%
# 4           8       30.8%

# %%
# 只选一个最近的年份
math = math.loc[math.Year==2011, :]

# %%
len(math.DBN) - math.DBN.nunique()
# Out:
# 3818

# %%
math.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4950 entries, 5 to 28477
# Data columns (total 16 columns):
# DBN                 4950 non-null object
# Grade               4950 non-null object
# Year                4950 non-null int64
# Category            4950 non-null object
# Number Tested       4950 non-null int64
# Mean Scale Score    4950 non-null object
# Level 1 #           4950 non-null object
# Level 1 %           4950 non-null object
# Level 2 #           4950 non-null object
# Level 2 %           4950 non-null object
# Level 3 #           4950 non-null object
# Level 3 %           4950 non-null object
# Level 4 #           4950 non-null object
# Level 4 %           4950 non-null object
# Level 3+4 #         4950 non-null object
# Level 3+4 %         4950 non-null object
# dtypes: int64(2), object(14)
# memory usage: 657.4+ KB

# %%
# 去掉一些无关的col
math.Category.value_counts()
# Out:
# All Students    4950
# Name: Category, dtype: int64

# %%
math.columns
# Out:
# Index(['DBN', 'Grade', 'Year', 'Category', 'Number Tested', 'Mean Scale Score',
#        'Level 1 #', 'Level 1 %', 'Level 2 #', 'Level 2 %', 'Level 3 #',
#        'Level 3 %', 'Level 4 #', 'Level 4 %', 'Level 3+4 #', 'Level 3+4 %'],
#       dtype='object')

# %%
['Level 1 #', 'Level 1 %', 'Level 2 #', 'Level 2 %', 
 'Level 3 #', 'Level 3 %', 'Level 4 #', 'Level 4 %', 
 'Level 3+4 #', 'Level 3+4 %'][1::2]
# Out:
# ['Level 1 %', 'Level 2 %', 'Level 3 %', 'Level 4 %', 'Level 3+4 %']

# %%
# trim off redundant cols
math = math[['DBN', 'Number Tested', 'Mean Scale Score',
            'Level 1 %', 'Level 2 %', 'Level 3 %', 'Level 4 %', 'Level 3+4 %']]

# %%
math.info()
math.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4950 entries, 5 to 28477
# Data columns (total 8 columns):
# DBN                 4950 non-null object
# Number Tested       4950 non-null int64
# Mean Scale Score    4950 non-null object
# Level 1 %           4950 non-null object
# Level 2 %           4950 non-null object
# Level 3 %           4950 non-null object
# Level 4 %           4950 non-null object
# Level 3+4 %         4950 non-null object
# dtypes: int64(1), object(7)
# memory usage: 348.0+ KB
#        DBN  Number Tested Mean Scale Score Level 1 % Level 2 % Level 3 %  \
# 5   01M015             28              671     35.7%     46.4%     17.9%
# 11  01M015             28              668     10.7%       50%     32.1%
# 17  01M015             25              667       20%       32%       48%
# 24  01M015             81              669     22.2%     43.2%     32.1%
# 30  01M019             34              679      5.9%     67.6%     20.6%
#
#    Level 4 % Level 3+4 %
# 5         0%       17.9%
# 11      7.1%       39.3%
# 17        0%         48%
# 24      2.5%       34.6%
# 30      5.9%       26.5%

# %%
# 转换数据格式
for col in ['Mean Scale Score', 'Level 1 %', 'Level 2 %', 'Level 3 %', 
            'Level 4 %', 'Level 3+4 %']:
    math[col] = math[col].str.replace('%', '')
    math[col] = pd.to_numeric(math[col], errors='coerce')

# %%
math.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4950 entries, 5 to 28477
# Data columns (total 8 columns):
# DBN                 4950 non-null object
# Number Tested       4950 non-null int64
# Mean Scale Score    4882 non-null float64
# Level 1 %           4882 non-null float64
# Level 2 %           4882 non-null float64
# Level 3 %           4882 non-null float64
# Level 4 %           4882 non-null float64
# Level 3+4 %         4882 non-null float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 348.0+ KB

# %%
math.head()
# Out:
#        DBN  Number Tested  Mean Scale Score  Level 1 %  Level 2 %  Level 3 %  \
# 5   01M015             28             671.0       35.7       46.4       17.9
# 11  01M015             28             668.0       10.7       50.0       32.1
# 17  01M015             25             667.0       20.0       32.0       48.0
# 24  01M015             81             669.0       22.2       43.2       32.1
# 30  01M019             34             679.0        5.9       67.6       20.6
#
#     Level 4 %  Level 3+4 %
# 5         0.0         17.9
# 11        7.1         39.3
# 17        0.0         48.0
# 24        2.5         34.6
# 30        5.9         26.5

# %%
math = math.groupby('DBN').mean().reset_index()

# %%
len(math.DBN) - math.DBN.nunique()
# Out:
# 0

# %%
data['math_test_results'] = math

# %% [markdown]
# ### clean 'graduation' dataset

# %%
data['graduation'].head()
# Out:
#     Demographic     DBN                            School Name    Cohort  \
# 0  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL      2003
# 1  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL      2004
# 2  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL      2005
# 3  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL      2006
# 4  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL  2006 Aug
#
#    Total Cohort Total Grads - n Total Grads - % of cohort Total Regents - n  \
# 0             5               s                         s                 s
# 1            55              37                     67.3%                17
# 2            64              43                     67.2%                27
# 3            78              43                     55.1%                36
# 4            78              44                     56.4%                37
#
#   Total Regents - % of cohort Total Regents - % of grads  \
# 0                           s                          s
# 1                       30.9%                      45.9%
# 2                       42.2%                      62.8%
# 3                       46.2%                      83.7%
# 4                       47.4%                      84.1%
#
#              ...            Regents w/o Advanced - n  \
# 0            ...                                   s
# 1            ...                                  17
# 2            ...                                  27
# 3            ...                                  36
# 4            ...                                  37
#
#   Regents w/o Advanced - % of cohort Regents w/o Advanced - % of grads  \
# 0                                  s                                 s
# 1                              30.9%                             45.9%
# 2                              42.2%                             62.8%
# 3                              46.2%                             83.7%
# 4                              47.4%                             84.1%
#
#   Local - n Local - % of cohort   Local - % of grads Still Enrolled - n  \
# 0         s                   s                    s                  s
# 1        20               36.4%                54.1%                 15
# 2        16                 25%  37.200000000000003%                  9
# 3         7                  9%                16.3%                 16
# 4         7                  9%                15.9%                 15
#
#   Still Enrolled - % of cohort Dropped Out - n Dropped Out - % of cohort
# 0                            s               s                         s
# 1                        27.3%               3                      5.5%
# 2                        14.1%               9                     14.1%
# 3                        20.5%              11                     14.1%
# 4                        19.2%              11                     14.1%
#
# [5 rows x 23 columns]

# %%
grad = data['graduation']

# %%
grad.Cohort.value_counts()
# Out:
# 2006 Aug    4131
# 2006        4130
# 2005        3963
# 2004        3708
# 2003        3432
# 2002        3095
# 2001        2637
# Name: Cohort, dtype: int64

# %%
grad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25096 entries, 0 to 25095
# Data columns (total 23 columns):
# Demographic                           25096 non-null object
# DBN                                   25096 non-null object
# School Name                           25096 non-null object
# Cohort                                25096 non-null object
# Total Cohort                          25096 non-null int64
# Total Grads - n                       25096 non-null object
# Total Grads - % of cohort             25096 non-null object
# Total Regents - n                     25096 non-null object
# Total Regents - % of cohort           25096 non-null object
# Total Regents - % of grads            25051 non-null object
# Advanced Regents - n                  25096 non-null object
# Advanced Regents - % of cohort        25096 non-null object
# Advanced Regents - % of grads         25051 non-null object
# Regents w/o Advanced - n              25096 non-null object
# Regents w/o Advanced - % of cohort    25096 non-null object
# Regents w/o Advanced - % of grads     25051 non-null object
# Local - n                             25096 non-null object
# Local - % of cohort                   25096 non-null object
# Local - % of grads                    25051 non-null object
# Still Enrolled - n                    25096 non-null object
# Still Enrolled - % of cohort          25096 non-null object
# Dropped Out - n                       25096 non-null object
# Dropped Out - % of cohort             25096 non-null object
# dtypes: int64(1), object(22)
# memory usage: 4.4+ MB

# %% [markdown]
# Do some google search I know that there are three types of diploma: advanced rengents, rengents, and local. The former is better than the latter.

# %%
grad.head()
# Out:
#     Demographic     DBN                            School Name    Cohort  \
# 0  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL      2003
# 1  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL      2004
# 2  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL      2005
# 3  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL      2006
# 4  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL  2006 Aug
#
#    Total Cohort Total Grads - n Total Grads - % of cohort Total Regents - n  \
# 0             5               s                         s                 s
# 1            55              37                     67.3%                17
# 2            64              43                     67.2%                27
# 3            78              43                     55.1%                36
# 4            78              44                     56.4%                37
#
#   Total Regents - % of cohort Total Regents - % of grads  \
# 0                           s                          s
# 1                       30.9%                      45.9%
# 2                       42.2%                      62.8%
# 3                       46.2%                      83.7%
# 4                       47.4%                      84.1%
#
#              ...            Regents w/o Advanced - n  \
# 0            ...                                   s
# 1            ...                                  17
# 2            ...                                  27
# 3            ...                                  36
# 4            ...                                  37
#
#   Regents w/o Advanced - % of cohort Regents w/o Advanced - % of grads  \
# 0                                  s                                 s
# 1                              30.9%                             45.9%
# 2                              42.2%                             62.8%
# 3                              46.2%                             83.7%
# 4                              47.4%                             84.1%
#
#   Local - n Local - % of cohort   Local - % of grads Still Enrolled - n  \
# 0         s                   s                    s                  s
# 1        20               36.4%                54.1%                 15
# 2        16                 25%  37.200000000000003%                  9
# 3         7                  9%                16.3%                 16
# 4         7                  9%                15.9%                 15
#
#   Still Enrolled - % of cohort Dropped Out - n Dropped Out - % of cohort
# 0                            s               s                         s
# 1                        27.3%               3                      5.5%
# 2                        14.1%               9                     14.1%
# 3                        20.5%              11                     14.1%
# 4                        19.2%              11                     14.1%
#
# [5 rows x 23 columns]

# %%
mask = grad['Total Regents - % of cohort'] == grad['Regents w/o Advanced - % of cohort']

# %%
grad[~mask]
# Out:
#         Demographic     DBN                            School Name    Cohort  \
# 5      Total Cohort  01M448    UNIVERSITY NEIGHBORHOOD HIGH SCHOOL      2001
# 6      Total Cohort  01M448    UNIVERSITY NEIGHBORHOOD HIGH SCHOOL      2002
# 7      Total Cohort  01M448    UNIVERSITY NEIGHBORHOOD HIGH SCHOOL      2003
# 8      Total Cohort  01M448    UNIVERSITY NEIGHBORHOOD HIGH SCHOOL      2004
# 9      Total Cohort  01M448    UNIVERSITY NEIGHBORHOOD HIGH SCHOOL      2005
# 10     Total Cohort  01M448    UNIVERSITY NEIGHBORHOOD HIGH SCHOOL      2006
# 11     Total Cohort  01M448    UNIVERSITY NEIGHBORHOOD HIGH SCHOOL  2006 Aug
# 20     Total Cohort  01M509                MARTA VALLE HIGH SCHOOL      2002
# 22     Total Cohort  01M509                MARTA VALLE HIGH SCHOOL      2004
# 23     Total Cohort  01M509                MARTA VALLE HIGH SCHOOL      2005
# 24     Total Cohort  01M509                MARTA VALLE HIGH SCHOOL      2006
# 25     Total Cohort  01M509                MARTA VALLE HIGH SCHOOL  2006 Aug
# 28     Total Cohort  01M515  LOWER EAST SIDE PREPARATORY HIGH SCHO      2003
# 29     Total Cohort  01M515  LOWER EAST SIDE PREPARATORY HIGH SCHO      2004
# 30     Total Cohort  01M515  LOWER EAST SIDE PREPARATORY HIGH SCHO      2005
# 31     Total Cohort  01M515  LOWER EAST SIDE PREPARATORY HIGH SCHO      2006
# 32     Total Cohort  01M515  LOWER EAST SIDE PREPARATORY HIGH SCHO  2006 Aug
# 35     Total Cohort  01M539  NEW EXPLORATIONS INTO SCIENCE  TECHNO      2003
# 36     Total Cohort  01M539  NEW EXPLORATIONS INTO SCIENCE  TECHNO      2004
# 37     Total Cohort  01M539  NEW EXPLORATIONS INTO SCIENCE  TECHNO      2005
# 38     Total Cohort  01M539  NEW EXPLORATIONS INTO SCIENCE  TECHNO      2006
# 39     Total Cohort  01M539  NEW EXPLORATIONS INTO SCIENCE  TECHNO  2006 Aug
# 76     Total Cohort  02M296  HIGH SCHOOL OF HOSPITALITY MANAGEMENT      2005
# 77     Total Cohort  02M296  HIGH SCHOOL OF HOSPITALITY MANAGEMENT      2006
# 78     Total Cohort  02M296  HIGH SCHOOL OF HOSPITALITY MANAGEMENT  2006 Aug
# 81     Total Cohort  02M298                       PACE HIGH SCHOOL      2004
# 82     Total Cohort  02M298                       PACE HIGH SCHOOL      2005
# 83     Total Cohort  02M298                       PACE HIGH SCHOOL      2006
# 84     Total Cohort  02M298                       PACE HIGH SCHOOL  2006 Aug
# 87     Total Cohort  02M300  URBAN ASSEMBLY SCHOOL OF DESIGN AND C      2004
# ...             ...     ...                                    ...       ...
# 25038          Male  31R600  RALPH R. MCKEE CAREER AND TECHNICAL E      2002
# 25039          Male  31R600  RALPH R. MCKEE CAREER AND TECHNICAL E      2003
# 25040          Male  31R600  RALPH R. MCKEE CAREER AND TECHNICAL E      2004
# 25041          Male  31R600  RALPH R. MCKEE CAREER AND TECHNICAL E      2005
# 25042          Male  31R600  RALPH R. MCKEE CAREER AND TECHNICAL E      2006
# 25043          Male  31R600  RALPH R. MCKEE CAREER AND TECHNICAL E  2006 Aug
# 25044          Male  31R605    STATEN ISLAND TECHNICAL HIGH SCHOOL      2001
# 25045          Male  31R605    STATEN ISLAND TECHNICAL HIGH SCHOOL      2002
# 25046          Male  31R605    STATEN ISLAND TECHNICAL HIGH SCHOOL      2003
# 25047          Male  31R605    STATEN ISLAND TECHNICAL HIGH SCHOOL      2004
# 25048          Male  31R605    STATEN ISLAND TECHNICAL HIGH SCHOOL      2005
# 25049          Male  31R605    STATEN ISLAND TECHNICAL HIGH SCHOOL      2006
# 25050          Male  31R605    STATEN ISLAND TECHNICAL HIGH SCHOOL  2006 Aug
# 25053          Male  32K403   ACADEMY FOR ENVIRONMENTAL LEADERSHIP      2006
# 25054          Male  32K403   ACADEMY FOR ENVIRONMENTAL LEADERSHIP  2006 Aug
# 25058          Male  32K545  EBC HIGH SCHOOL FOR PUBLIC SERVICEBU      2001
# 25059          Male  32K545  EBC HIGH SCHOOL FOR PUBLIC SERVICEBU      2002
# 25060          Male  32K545  EBC HIGH SCHOOL FOR PUBLIC SERVICEBU      2003
# 25061          Male  32K545  EBC HIGH SCHOOL FOR PUBLIC SERVICEBU      2004
# 25062          Male  32K545  EBC HIGH SCHOOL FOR PUBLIC SERVICEBU      2005
# 25068          Male  32K549     BUSHWICK SCHOOL FOR SOCIAL JUSTICE      2005
# 25069          Male  32K549     BUSHWICK SCHOOL FOR SOCIAL JUSTICE      2006
# 25070          Male  32K549     BUSHWICK SCHOOL FOR SOCIAL JUSTICE  2006 Aug
# 25073          Male  32K552              ACADEMY OF URBAN PLANNING      2004
# 25080          Male  32K554   ALL CITY LEADERSHIP SECONDARY SCHOOL      2005
# 25081          Male  32K554   ALL CITY LEADERSHIP SECONDARY SCHOOL      2006
# 25082          Male  32K554   ALL CITY LEADERSHIP SECONDARY SCHOOL  2006 Aug
# 25085          Male  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACAD      2004
# 25087          Male  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACAD      2006
# 25088          Male  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACAD  2006 Aug
#
#        Total Cohort Total Grads - n Total Grads - % of cohort  \
# 5                64              46       71.900000000000006%
# 6                52              33                     63.5%
# 7                87              67                       77%
# 8               112              75                       67%
# 9               121              64                     52.9%
# 10              124              53                     42.7%
# 11              124              60                     48.4%
# 20               55              22                       40%
# 22               65              29                     44.6%
# 23               88              49                     55.7%
# 24               84              47                       56%
# 25               84              50                     59.5%
# 28              205              86                       42%
# 29              200              97                     48.5%
# 30              154              70                     45.5%
# 31              193             105                     54.4%
# 32              193             105                     54.4%
# 35               58              58                      100%
# 36               60              58                     96.7%
# 37               49              47                     95.9%
# 38               46              46                      100%
# 39               46              46                      100%
# 76               91              74                     81.3%
# 77               75              58                     77.3%
# 78               75              60                       80%
# 81              115              98                     85.2%
# 82               98              82                     83.7%
# 83               92              78                     84.8%
# 84               92              79                     85.9%
# 87               83              57                     68.7%
# ...             ...             ...                       ...
# 25038            81              50                     61.7%
# 25039            84              64                     76.2%
# 25040           104              63                     60.6%
# 25041           111              67                     60.4%
# 25042           124              75                     60.5%
# 25043           124              78                     62.9%
# 25044           105              83                       79%
# 25045            86              84                     97.7%
# 25046            83              83                      100%
# 25047           100             100                      100%
# 25048           101             101                      100%
# 25049           174             173                     99.4%
# 25050           174             174                      100%
# 25053            44              26                     59.1%
# 25054            44              30                     68.2%
# 25058            42              29                       69%
# 25059            54              31                     57.4%
# 25060            58              34                     58.6%
# 25061            72              36                       50%
# 25062            68              41                     60.3%
# 25068            49              34                     69.4%
# 25069            45              32                     71.1%
# 25070            45              32                     71.1%
# 25073            47              25                     53.2%
# 25080            23              16                     69.6%
# 25081            24              21                     87.5%
# 25082            24              22                     91.7%
# 25085            34              22                     64.7%
# 25087            51              25                       49%
# 25088            51              26                       51%
#
#       Total Regents - n Total Regents - % of cohort  \
# 5                    32                         50%
# 6                    19                       36.5%
# 7                    39                       44.8%
# 8                    36                       32.1%
# 9                    35                       28.9%
# 10                   42                       33.9%
# 11                   42                       33.9%
# 20                   11                         20%
# 22                   13                         20%
# 23                   38                       43.2%
# 24                   40                       47.6%
# 25                   41                       48.8%
# 28                   71                       34.6%
# 29                   74                         37%
# 30                   56                       36.4%
# 31                   91                       47.2%
# 32                   91                       47.2%
# 35                   57                       98.3%
# 36                   58                       96.7%
# 37                   47                       95.9%
# 38                   46                        100%
# 39                   46                        100%
# 76                   63                       69.2%
# 77                   50                       66.7%
# 78                   52                       69.3%
# 81                   98                       85.2%
# 82                   77         78.599999999999994%
# 83                   76                       82.6%
# 84                   77                       83.7%
# 87                   53                       63.9%
# ...                 ...                         ...
# 25038                33                       40.7%
# 25039                44                       52.4%
# 25040                49                       47.1%
# 25041                47                       42.3%
# 25042                61                       49.2%
# 25043                63                       50.8%
# 25044                83                         79%
# 25045                84                       97.7%
# 25046                83                        100%
# 25047               100                        100%
# 25048               101                        100%
# 25049               173                       99.4%
# 25050               174                        100%
# 25053                17                       38.6%
# 25054                19                       43.2%
# 25058                 4                        9.5%
# 25059                12                       22.2%
# 25060                17                       29.3%
# 25061                 9                       12.5%
# 25062                17                         25%
# 25068                17                       34.7%
# 25069                25                       55.6%
# 25070                25                       55.6%
# 25073                10                       21.3%
# 25080                12                       52.2%
# 25081                14                       58.3%
# 25082                15                       62.5%
# 25085                10                       29.4%
# 25087                 8                       15.7%
# 25088                 8                       15.7%
#
#       Total Regents - % of grads            ...             \
# 5            69.599999999999994%            ...
# 6                          57.6%            ...
# 7                          58.2%            ...
# 8                            48%            ...
# 9                          54.7%            ...
# 10                         79.2%            ...
# 11                           70%            ...
# 20                           50%            ...
# 22                         44.8%            ...
# 23           77.599999999999994%            ...
# 24                         85.1%            ...
# 25                           82%            ...
# 28                         82.6%            ...
# 29                         76.3%            ...
# 30                           80%            ...
# 31                         86.7%            ...
# 32                         86.7%            ...
# 35                         98.3%            ...
# 36                          100%            ...
# 37                          100%            ...
# 38                          100%            ...
# 39                          100%            ...
# 76                         85.1%            ...
# 77                         86.2%            ...
# 78                         86.7%            ...
# 81                          100%            ...
# 82                         93.9%            ...
# 83                         97.4%            ...
# 84                         97.5%            ...
# 87                           93%            ...
# ...                          ...            ...
# 25038                        66%            ...
# 25039                      68.8%            ...
# 25040                      77.8%            ...
# 25041                      70.1%            ...
# 25042                      81.3%            ...
# 25043                      80.8%            ...
# 25044                       100%            ...
# 25045                       100%            ...
# 25046                       100%            ...
# 25047                       100%            ...
# 25048                       100%            ...
# 25049                       100%            ...
# 25050                       100%            ...
# 25053                      65.4%            ...
# 25054                      63.3%            ...
# 25058                      13.8%            ...
# 25059                      38.7%            ...
# 25060                        50%            ...
# 25061                        25%            ...
# 25062                      41.5%            ...
# 25068                        50%            ...
# 25069                      78.1%            ...
# 25070                      78.1%            ...
# 25073                        40%            ...
# 25080                        75%            ...
# 25081                      66.7%            ...
# 25082                      68.2%            ...
# 25085                      45.5%            ...
# 25087                        32%            ...
# 25088                      30.8%            ...
#
#       Regents w/o Advanced - n Regents w/o Advanced - % of cohort  \
# 5                           25                              39.1%
# 6                           11                              21.2%
# 7                           28                32.200000000000003%
# 8                           30                              26.8%
# 9                           31                              25.6%
# 10                          34                              27.4%
# 11                          34                              27.4%
# 20                           7                              12.7%
# 22                          10                              15.4%
# 23                          20                              22.7%
# 24                          23                              27.4%
# 25                          23                              27.4%
# 28                          23                              11.2%
# 29                          14                                 7%
# 30                          11                               7.1%
# 31                          22                              11.4%
# 32                          22                              11.4%
# 35                           8                              13.8%
# 36                           4                               6.7%
# 37                           9                18.399999999999999%
# 38                          15                              32.6%
# 39                          15                              32.6%
# 76                          57                              62.6%
# 77                          49                              65.3%
# 78                          51                                68%
# 81                          57                              49.6%
# 82                          64                              65.3%
# 83                          37                40.200000000000003%
# 84                          38                              41.3%
# 87                          51                              61.4%
# ...                        ...                                ...
# 25038                       26                              32.1%
# 25039                       18                              21.4%
# 25040                       36                              34.6%
# 25041                       13                              11.7%
# 25042                       16                              12.9%
# 25043                       18                              14.5%
# 25044                        2                               1.9%
# 25045                        0                                 0%
# 25046                        3                               3.6%
# 25047                        2                                 2%
# 25048                        2                                 2%
# 25049                       10                               5.7%
# 25050                       11                               6.3%
# 25053                       15                              34.1%
# 25054                       17                              38.6%
# 25058                        0                                 0%
# 25059                       10                              18.5%
# 25060                       13                              22.4%
# 25061                        6                               8.3%
# 25062                        9                              13.2%
# 25068                       16                              32.7%
# 25069                       22                              48.9%
# 25070                       22                              48.9%
# 25073                        9                              19.1%
# 25080                        9                              39.1%
# 25081                       11                              45.8%
# 25082                       12                                50%
# 25085                        9                              26.5%
# 25087                        7                              13.7%
# 25088                        7                              13.7%
#
#       Regents w/o Advanced - % of grads Local - n  Local - % of cohort  \
# 5                                 54.3%        14                21.9%
# 6                   33.299999999999997%        14                26.9%
# 7                                 41.8%        28  32.200000000000003%
# 8                                   40%        39  34.799999999999997%
# 9                                 48.4%        29                  24%
# 10                                64.2%        11                 8.9%
# 11                                56.7%        18                14.5%
# 20                                31.8%        11                  20%
# 22                                34.5%        16                24.6%
# 23                  40.799999999999997%        11                12.5%
# 24                                48.9%         7   8.300000000000001%
# 25                                  46%         9                10.7%
# 28                                26.7%        15                 7.3%
# 29                                14.4%        23                11.5%
# 30                                15.7%        14                 9.1%
# 31                                  21%        14                 7.3%
# 32                                  21%        14                 7.3%
# 35                                13.8%         1                 1.7%
# 36                                 6.9%         0                   0%
# 37                  19.100000000000001%         0                   0%
# 38                                32.6%         0                   0%
# 39                                32.6%         0                   0%
# 76                                  77%        11                12.1%
# 77                                84.5%         8                10.7%
# 78                                  85%         8                10.7%
# 81                                58.2%         0                   0%
# 82                                  78%         5                 5.1%
# 83                                47.4%         2                 2.2%
# 84                                48.1%         2                 2.2%
# 87                                89.5%         4                 4.8%
# ...                                 ...       ...                  ...
# 25038                               52%        17                  21%
# 25039                             28.1%        20                23.8%
# 25040                             57.1%        14                13.5%
# 25041                             19.4%        20                  18%
# 25042                             21.3%        14                11.3%
# 25043                             23.1%        15                12.1%
# 25044                              2.4%         0                   0%
# 25045                                0%         0                   0%
# 25046                              3.6%         0                   0%
# 25047                                2%         0                   0%
# 25048                                2%         0                   0%
# 25049                              5.8%         0                   0%
# 25050                              6.3%         0                   0%
# 25053                             57.7%         9                20.5%
# 25054                             56.7%        11                  25%
# 25058                                0%        25                59.5%
# 25059                             32.3%        19                35.2%
# 25060                             38.2%        17                29.3%
# 25061                             16.7%        27                37.5%
# 25062                               22%        24                35.3%
# 25068                             47.1%        17                34.7%
# 25069                             68.8%         7                15.6%
# 25070                             68.8%         7                15.6%
# 25073                               36%        15                31.9%
# 25080                             56.3%         4                17.4%
# 25081                             52.4%         7                29.2%
# 25082                             54.5%         7                29.2%
# 25085                             40.9%        12                35.3%
# 25087                               28%        17                33.3%
# 25088                             26.9%        18                35.3%
#
#         Local - % of grads Still Enrolled - n Still Enrolled - % of cohort  \
# 5                    30.4%                 10                        15.6%
# 6                    42.4%                 16                        30.8%
# 7                    41.8%                  9                        10.3%
# 8                      52%                 33                        29.5%
# 9                    45.3%                 41                        33.9%
# 10                   20.8%                 46                        37.1%
# 11                     30%                 39                        31.5%
# 20                     50%                 18          32.700000000000003%
# 22                   55.2%                 27                        41.5%
# 23                   22.4%                 20                        22.7%
# 24                   14.9%                 25                        29.8%
# 25                     18%                 22                        26.2%
# 28     17.399999999999999%                 80                          39%
# 29                   23.7%                 78                          39%
# 30                     20%                 64                        41.6%
# 31                   13.3%                 53                        27.5%
# 32                   13.3%                 53                        27.5%
# 35                    1.7%                  0                           0%
# 36                      0%                  0                           0%
# 37                      0%                  2                         4.1%
# 38                      0%                  0                           0%
# 39                      0%                  0                           0%
# 76                   14.9%                 11                        12.1%
# 77                   13.8%                 11                        14.7%
# 78                   13.3%                  9                          12%
# 81                      0%                  8                           7%
# 82                    6.1%                 13                        13.3%
# 83                    2.6%                  6                         6.5%
# 84                    2.5%                  5                         5.4%
# 87                      7%                 21                        25.3%
# ...                    ...                ...                          ...
# 25038                  34%               20.0                        24.7%
# 25039                31.3%               11.0                        13.1%
# 25040                22.2%               21.0                        20.2%
# 25041                29.9%               27.0                        24.3%
# 25042                18.7%               30.0                        24.2%
# 25043                19.2%               27.0                        21.8%
# 25044                   0%               19.0                        18.1%
# 25045                   0%                1.0                         1.2%
# 25046                   0%                0.0                           0%
# 25047                   0%                0.0                           0%
# 25048                   0%                0.0                           0%
# 25049                   0%                1.0                         0.6%
# 25050                   0%                0.0                           0%
# 25053                34.6%               14.0                        31.8%
# 25054                36.7%               10.0                        22.7%
# 25058                86.2%               13.0                          31%
# 25059                61.3%               16.0                        29.6%
# 25060                  50%               19.0                        32.8%
# 25061                  75%               27.0                        37.5%
# 25062                58.5%               22.0                        32.4%
# 25068                  50%               11.0                        22.4%
# 25069                21.9%                8.0                        17.8%
# 25070                21.9%                8.0                        17.8%
# 25073                  60%               18.0                        38.3%
# 25080                  25%                7.0                        30.4%
# 25081                33.3%                2.0                         8.3%
# 25082                31.8%                1.0                         4.2%
# 25085                54.5%                8.0                        23.5%
# 25087                  68%               12.0                        23.5%
# 25088                69.2%               11.0                        21.6%
#
#       Dropped Out - n Dropped Out - % of cohort
# 5                   6                      9.4%
# 6                   1                      1.9%
# 7                  11                     12.6%
# 8                   4                      3.6%
# 9                  11                      9.1%
# 10                 20       16.100000000000001%
# 11                 20       16.100000000000001%
# 20                 11                       20%
# 22                  8                     12.3%
# 23                 14                     15.9%
# 24                  5                        6%
# 25                  5                        6%
# 28                 39                       19%
# 29                 25                     12.5%
# 30                 20                       13%
# 31                 35       18.100000000000001%
# 32                 35       18.100000000000001%
# 35                  0                        0%
# 36                  2                      3.3%
# 37                  0                        0%
# 38                  0                        0%
# 39                  0                        0%
# 76                  4                      4.4%
# 77                  5                      6.7%
# 78                  5                      6.7%
# 81                  7                      6.1%
# 82                  2                        2%
# 83                  4                      4.3%
# 84                  4                      4.3%
# 87                  5                        6%
# ...               ...                       ...
# 25038             4.0                      4.9%
# 25039             6.0                      7.1%
# 25040            15.0                     14.4%
# 25041             7.0                      6.3%
# 25042            11.0                      8.9%
# 25043            11.0                      8.9%
# 25044             3.0                      2.9%
# 25045             1.0                      1.2%
# 25046             0.0                        0%
# 25047             0.0                        0%
# 25048             0.0                        0%
# 25049             0.0                        0%
# 25050             0.0                        0%
# 25053             4.0                      9.1%
# 25054             4.0                      9.1%
# 25058             0.0                        0%
# 25059             6.0                     11.1%
# 25060             4.0                      6.9%
# 25061             9.0                     12.5%
# 25062             4.0                      5.9%
# 25068             4.0                      8.2%
# 25069             5.0                     11.1%
# 25070             5.0                     11.1%
# 25073             2.0                      4.3%
# 25080             0.0                        0%
# 25081             1.0                      4.2%
# 25082             1.0                      4.2%
# 25085             3.0                      8.8%
# 25087            12.0                     23.5%
# 25088            12.0                     23.5%
#
# [10890 rows x 23 columns]

# %% [markdown]
# 从上面可以看出来，advanced rengent是total rangent的一个子集，而local, still enrolled, dropped out和total rangent没有交集。

# %%
# 进一步探究下col之间的的关系
sus_cols = ['DBN', 'Cohort', 'Total Cohort',
       'Total Grads - n',  'Total Regents - n', 
       'Advanced Regents - n', 'Regents w/o Advanced - n',
       'Local - n',  'Still Enrolled - n',
       'Dropped Out - n']
grad[sus_cols]
# Out:
#           DBN    Cohort  Total Cohort Total Grads - n Total Regents - n  \
# 0      01M292      2003             5               s                 s
# 1      01M292      2004            55              37                17
# 2      01M292      2005            64              43                27
# 3      01M292      2006            78              43                36
# 4      01M292  2006 Aug            78              44                37
# 5      01M448      2001            64              46                32
# 6      01M448      2002            52              33                19
# 7      01M448      2003            87              67                39
# 8      01M448      2004           112              75                36
# 9      01M448      2005           121              64                35
# 10     01M448      2006           124              53                42
# 11     01M448  2006 Aug           124              60                42
# 12     01M450      2001            61              41                40
# 13     01M450      2002            72              45                45
# 14     01M450      2003            79              49                44
# 15     01M450      2004            80              58                48
# 16     01M450      2005            85              61                58
# 17     01M450      2006            90              70                67
# 18     01M450  2006 Aug            90              71                68
# 19     01M509      2001            69              34                 6
# 20     01M509      2002            55              22                11
# 21     01M509      2003            70              31                22
# 22     01M509      2004            65              29                13
# 23     01M509      2005            88              49                38
# 24     01M509      2006            84              47                40
# 25     01M509  2006 Aug            84              50                41
# 26     01M515      2001           166              88                36
# 27     01M515      2002           172              77                53
# 28     01M515      2003           205              86                71
# 29     01M515      2004           200              97                74
# ...       ...       ...           ...             ...               ...
# 25066  32K549      2003            49              28                 8
# 25067  32K549      2004            54              38                15
# 25068  32K549      2005            49              34                17
# 25069  32K549      2006            45              32                25
# 25070  32K549  2006 Aug            45              32                25
# 25071  32K552      2002             3               s                 s
# 25072  32K552      2003            63              31                14
# 25073  32K552      2004            47              25                10
# 25074  32K552      2005            53              28                 9
# 25075  32K552      2006            50              21                19
# 25076  32K552  2006 Aug            50              27                21
# 25077  32K554      2002             2               s                 s
# 25078  32K554      2003            13               s                 s
# 25079  32K554      2004            11               s                 s
# 25080  32K554      2005            23              16                12
# 25081  32K554      2006            24              21                14
# 25082  32K554  2006 Aug            24              22                15
# 25083  32K556      2002             2               s                 s
# 25084  32K556      2003            47              30                 3
# 25085  32K556      2004            34              22                10
# 25086  32K556      2005            40              25                 9
# 25087  32K556      2006            51              25                 8
# 25088  32K556  2006 Aug            51              26                 8
# 25089  32K564      2001            69               2                 0
# 25090  32K564      2002            73               4                 0
# 25091  32K564      2003            65               1                 0
# 25092  32K564      2004            64               2                 0
# 25093  32K564      2005            79               3                 1
# 25094  32K564      2006            57               4                 2
# 25095  32K564  2006 Aug            57               4                 2
#
#       Advanced Regents - n Regents w/o Advanced - n Local - n  \
# 0                        s                        s         s
# 1                        0                       17        20
# 2                        0                       27        16
# 3                        0                       36         7
# 4                        0                       37         7
# 5                        7                       25        14
# 6                        8                       11        14
# 7                       11                       28        28
# 8                        6                       30        39
# 9                        4                       31        29
# 10                       8                       34        11
# 11                       8                       34        18
# 12                       0                       40         1
# 13                       0                       45         0
# 14                       0                       44         5
# 15                       0                       48        10
# 16                       0                       58         3
# 17                       0                       67         3
# 18                       0                       68         3
# 19                       0                        6        28
# 20                       4                        7        11
# 21                       0                       22         9
# 22                       3                       10        16
# 23                      18                       20        11
# 24                      17                       23         7
# 25                      18                       23         9
# 26                       0                       36        53
# 27                       0                       53        24
# 28                      48                       23        15
# 29                      60                       14        23
# ...                    ...                      ...       ...
# 25066                    0                        8        20
# 25067                    0                       15        23
# 25068                    1                       16        17
# 25069                    3                       22         7
# 25070                    3                       22         7
# 25071                    s                        s         s
# 25072                    0                       14        17
# 25073                    1                        9        15
# 25074                    0                        9        19
# 25075                    0                       19         2
# 25076                    0                       21         6
# 25077                    s                        s         s
# 25078                    s                        s         s
# 25079                    s                        s         s
# 25080                    3                        9         4
# 25081                    3                       11         7
# 25082                    3                       12         7
# 25083                    s                        s         s
# 25084                    0                        3        27
# 25085                    1                        9        12
# 25086                    0                        9        16
# 25087                    1                        7        17
# 25088                    1                        7        18
# 25089                    0                        0         2
# 25090                    0                        0         4
# 25091                    0                        0         1
# 25092                    0                        0         2
# 25093                    0                        1         2
# 25094                    0                        2         2
# 25095                    0                        2         2
#
#       Still Enrolled - n Dropped Out - n
# 0                      s               s
# 1                     15               3
# 2                      9               9
# 3                     16              11
# 4                     15              11
# 5                     10               6
# 6                     16               1
# 7                      9              11
# 8                     33               4
# 9                     41              11
# 10                    46              20
# 11                    39              20
# 12                     7              12
# 13                    18               7
# 14                    20              10
# 15                    13               9
# 16                    11               9
# 17                    15               5
# 18                    14               5
# 19                    19              10
# 20                    18              11
# 21                    20              18
# 22                    27               8
# 23                    20              14
# 24                    25               5
# 25                    22               5
# 26                    45              30
# 27                    67              28
# 28                    80              39
# 29                    78              25
# ...                  ...             ...
# 25066               15.0             5.0
# 25067                8.0             8.0
# 25068               11.0             4.0
# 25069                8.0             5.0
# 25070                8.0             5.0
# 25071                  s               s
# 25072               23.0             8.0
# 25073               18.0             2.0
# 25074               15.0             8.0
# 25075               24.0             2.0
# 25076               18.0             2.0
# 25077                  s               s
# 25078                  s               s
# 25079                  s               s
# 25080                7.0             0.0
# 25081                2.0             1.0
# 25082                1.0             1.0
# 25083                  s               s
# 25084               11.0             5.0
# 25085                8.0             3.0
# 25086                8.0             3.0
# 25087               12.0            12.0
# 25088               11.0            12.0
# 25089               63.0             4.0
# 25090               58.0            11.0
# 25091               44.0            20.0
# 25092               38.0            22.0
# 25093               46.0            28.0
# 25094               34.0            17.0
# 25095               34.0            17.0
#
# [25096 rows x 10 columns]

# %% [markdown]
# * 'Total Cohort'的层级结构和包含关系：
#     * 'Total Grads - n'
#         * 'Total Regents - n'
#             * 'Advanced Regents - n'
#             * 'Regents w/o Advanced - n'
#         * 'Local - n'
#     * 'Still Enrolled - n'
#     * 'Dropped Out - n'

# %%
# remove redundant cols
cols = ['DBN', 'School Name', 'Total Grads - % of cohort', 
       'Total Regents - % of cohort', 'Advanced Regents - % of cohort',  
       'Local - % of cohort', 'Still Enrolled - % of cohort', 'Dropped Out - % of cohort']

# %%
grad = grad[cols]

# %%
to_convert = ['Total Grads - % of cohort', 
       'Total Regents - % of cohort', 'Advanced Regents - % of cohort',  
       'Local - % of cohort', 'Still Enrolled - % of cohort', 'Dropped Out - % of cohort']

for col in to_convert:
    grad[col] = grad.loc[:, col].str.replace('%', '')
    grad[col] = pd.to_numeric(grad.loc[:, col], errors='coerce')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25096 entries, 0 to 25095
# Data columns (total 23 columns):
# Demographic                           25096 non-null object
# DBN                                   25096 non-null object
# School Name                           25096 non-null object
# Cohort                                25096 non-null object
# Total Cohort                          25096 non-null int64
# Total Grads - n                       25096 non-null object
# Total Grads - % of cohort             16704 non-null float64
# Total Regents - n                     25096 non-null object
# Total Regents - % of cohort           16704 non-null float64
# Total Regents - % of grads            25051 non-null object
# Advanced Regents - n                  25096 non-null object
# Advanced Regents - % of cohort        16704 non-null float64
# Advanced Regents - % of grads         25051 non-null object
# Regents w/o Advanced - n              25096 non-null object
# Regents w/o Advanced - % of cohort    25096 non-null object
# Regents w/o Advanced - % of grads     25051 non-null object
# Local - n                             25096 non-null object
# Local - % of cohort                   16704 non-null float64
# Local - % of grads                    25051 non-null object
# Still Enrolled - n                    25096 non-null object
# Still Enrolled - % of cohort          16704 non-null float64
# Dropped Out - n                       25096 non-null object
# Dropped Out - % of cohort             16704 non-null float64
# dtypes: float64(6), int64(1), object(16)
# memory usage: 4.4+ MB

# %%
grad.info()
grad.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25096 entries, 0 to 25095
# Data columns (total 8 columns):
# DBN                               25096 non-null object
# School Name                       25096 non-null object
# Total Grads - % of cohort         16704 non-null float64
# Total Regents - % of cohort       16704 non-null float64
# Advanced Regents - % of cohort    16704 non-null float64
# Local - % of cohort               16704 non-null float64
# Still Enrolled - % of cohort      16704 non-null float64
# Dropped Out - % of cohort         16704 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 1.5+ MB
#       DBN                            School Name  Total Grads - % of cohort  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL                        NaN
# 1  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL                       67.3
# 2  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL                       67.2
# 3  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL                       55.1
# 4  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL                       56.4
#
#    Total Regents - % of cohort  Advanced Regents - % of cohort  \
# 0                          NaN                             NaN
# 1                         30.9                             0.0
# 2                         42.2                             0.0
# 3                         46.2                             0.0
# 4                         47.4                             0.0
#
#    Local - % of cohort  Still Enrolled - % of cohort  \
# 0                  NaN                           NaN
# 1                 36.4                          27.3
# 2                 25.0                          14.1
# 3                  9.0                          20.5
# 4                  9.0                          19.2
#
#    Dropped Out - % of cohort
# 0                        NaN
# 1                        5.5
# 2                       14.1
# 3                       14.1
# 4                       14.1

# %%
grad = grad.groupby(['DBN','School Name']).mean().reset_index()

# %%
grad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 8 columns):
# DBN                               423 non-null object
# School Name                       423 non-null object
# Total Grads - % of cohort         400 non-null float64
# Total Regents - % of cohort       400 non-null float64
# Advanced Regents - % of cohort    400 non-null float64
# Local - % of cohort               400 non-null float64
# Still Enrolled - % of cohort      400 non-null float64
# Dropped Out - % of cohort         400 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 26.5+ KB

# %%
grad = grad.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 422
# Data columns (total 8 columns):
# DBN                               400 non-null object
# School Name                       400 non-null object
# Total Grads - % of cohort         400 non-null float64
# Total Regents - % of cohort       400 non-null float64
# Advanced Regents - % of cohort    400 non-null float64
# Local - % of cohort               400 non-null float64
# Still Enrolled - % of cohort      400 non-null float64
# Dropped Out - % of cohort         400 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 28.1+ KB
# None
# 0

# %%
grad.info()

print(len(grad.DBN) - grad.DBN.nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 422
# Data columns (total 8 columns):
# DBN                               400 non-null object
# School Name                       400 non-null object
# Total Grads - % of cohort         400 non-null float64
# Total Regents - % of cohort       400 non-null float64
# Advanced Regents - % of cohort    400 non-null float64
# Local - % of cohort               400 non-null float64
# Still Enrolled - % of cohort      400 non-null float64
# Dropped Out - % of cohort         400 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 28.1+ KB
# 0

# %%
data['graduation'] = grad

# %% [markdown]
# ### clean 'ap_2010'

# %%
data['ap_2010'].DBN.value_counts().head()
# Out:
# 04M610    2
# 12X248    1
# 07X551    1
# 11X418    1
# 11X299    1
# Name: DBN, dtype: int64

# %%
data['ap_2010'].loc[data['ap_2010'].DBN=='04M610', :]
# Out:
#        DBN                                         SchoolName AP Test Takers   \
# 51  04M610  THE YOUNG WOMEN'S LEADERSHIP SCHOOL OF EAST HA...              41
# 52  04M610                       YOUNG WOMEN'S LEADERSHIP SCH               s
#
#    Total Exams Taken Number of Exams with scores 3 4 or 5
# 51                55                                   29
# 52                 s                                    s

# %%
ap = data['ap_2010']
ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 5 columns):
# DBN                                     258 non-null object
# SchoolName                              258 non-null object
# AP Test Takers                          258 non-null object
# Total Exams Taken                       258 non-null object
# Number of Exams with scores 3 4 or 5    258 non-null object
# dtypes: object(5)
# memory usage: 10.2+ KB

# %%
ap.columns
# Out:
# Index(['DBN', 'SchoolName', 'AP Test Takers ', 'Total Exams Taken',
#        'Number of Exams with scores 3 4 or 5'],
#       dtype='object')

# %%
ap.columns = ap.columns.str.strip()

# %%
for col in ['AP Test Takers', 'Total Exams Taken',
       'Number of Exams with scores 3 4 or 5']:
    ap[col] = pd.to_numeric(ap.loc[:, col], errors='coerce')
    
ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 5 columns):
# DBN                                     258 non-null object
# SchoolName                              258 non-null object
# AP Test Takers                          233 non-null float64
# Total Exams Taken                       233 non-null float64
# Number of Exams with scores 3 4 or 5    151 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 10.2+ KB

# %%
ap['AP Test Takers'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237     True
# 238    False
# 239     True
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# 251    False
# 252     True
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# Name: AP Test Takers, dtype: bool

# %%
mask = (ap['AP Test Takers'].isnull()) & (ap['Total Exams Taken'].isnull()) & (ap['Number of Exams with scores 3 4 or 5'].isnull())

# %%
mask.sum()
# Out:
# 25

# %%
ap = ap[~mask]

# %%
ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233 entries, 0 to 257
# Data columns (total 5 columns):
# DBN                                     233 non-null object
# SchoolName                              233 non-null object
# AP Test Takers                          233 non-null float64
# Total Exams Taken                       233 non-null float64
# Number of Exams with scores 3 4 or 5    151 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 10.9+ KB

# %%
len(ap.DBN) - ap.DBN.nunique()
# Out:
# 0

# %%
data['ap_2010'] = ap

# %% [markdown]
# ### clean 'class_size'

# %%
data['class_size'].head()
# Out:
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# 1    1       M        M015  P.S. 015 Roberto Clemente     0K          CTT
# 2    1       M        M015  P.S. 015 Roberto Clemente     01       GEN ED
# 3    1       M        M015  P.S. 015 Roberto Clemente     01          CTT
# 4    1       M        M015  P.S. 015 Roberto Clemente     02       GEN ED
#
#   CORE SUBJECT (MS CORE and 9-12 ONLY) CORE COURSE (MS CORE and 9-12 ONLY)  \
# 0                                    -                                   -
# 1                                    -                                   -
# 2                                    -                                   -
# 3                                    -                                   -
# 4                                    -                                   -
#
#   SERVICE CATEGORY(K-9* ONLY)  NUMBER OF STUDENTS / SEATS FILLED  \
# 0                           -                               19.0
# 1                           -                               21.0
# 2                           -                               17.0
# 3                           -                               17.0
# 4                           -                               15.0
#
#    NUMBER OF SECTIONS  AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  \
# 0                 1.0                19.0                    19.0
# 1                 1.0                21.0                    21.0
# 2                 1.0                17.0                    17.0
# 3                 1.0                17.0                    17.0
# 4                 1.0                15.0                    15.0
#
#    SIZE OF LARGEST CLASS DATA SOURCE  SCHOOLWIDE PUPIL-TEACHER RATIO     DBN
# 0                   19.0         ATS                             NaN  01M015
# 1                   21.0         ATS                             NaN  01M015
# 2                   17.0         ATS                             NaN  01M015
# 3                   17.0         ATS                             NaN  01M015
# 4                   15.0         ATS                             NaN  01M015

# %%
cls = data['class_size']
cls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27611 entries, 0 to 27610
# Data columns (total 17 columns):
# CSD                                     27611 non-null int64
# BOROUGH                                 27611 non-null object
# SCHOOL CODE                             27611 non-null object
# SCHOOL NAME                             27611 non-null object
# GRADE                                   26127 non-null object
# PROGRAM TYPE                            26127 non-null object
# CORE SUBJECT (MS CORE and 9-12 ONLY)    26127 non-null object
# CORE COURSE (MS CORE and 9-12 ONLY)     26127 non-null object
# SERVICE CATEGORY(K-9* ONLY)             26127 non-null object
# NUMBER OF STUDENTS / SEATS FILLED       26127 non-null float64
# NUMBER OF SECTIONS                      26127 non-null float64
# AVERAGE CLASS SIZE                      26127 non-null float64
# SIZE OF SMALLEST CLASS                  26127 non-null float64
# SIZE OF LARGEST CLASS                   26127 non-null float64
# DATA SOURCE                             26127 non-null object
# SCHOOLWIDE PUPIL-TEACHER RATIO          1484 non-null float64
# DBN                                     27611 non-null object
# dtypes: float64(6), int64(1), object(10)
# memory usage: 3.6+ MB

# %%
cls.columns
# Out:
# Index(['CSD', 'BOROUGH', 'SCHOOL CODE', 'SCHOOL NAME', 'GRADE ',
#        'PROGRAM TYPE', 'CORE SUBJECT (MS CORE and 9-12 ONLY)',
#        'CORE COURSE (MS CORE and 9-12 ONLY)', 'SERVICE CATEGORY(K-9* ONLY)',
#        'NUMBER OF STUDENTS / SEATS FILLED', 'NUMBER OF SECTIONS',
#        'AVERAGE CLASS SIZE', 'SIZE OF SMALLEST CLASS', 'SIZE OF LARGEST CLASS',
#        'DATA SOURCE', 'SCHOOLWIDE PUPIL-TEACHER RATIO', 'DBN'],
#       dtype='object')

# %%
cls['PROGRAM TYPE'].value_counts()
# Out:
# GEN ED     14545
# CTT         7460
# SPEC ED     3653
# G&T          469
# Name: PROGRAM TYPE, dtype: int64

# %%
cls['GRADE '].value_counts()
# Out:
# 09-12      10644
# MS Core     4762
# 0K-09       1384
# 0K          1237
# 01          1185
# 02          1167
# 03          1143
# 04          1140
# 05          1086
# 06           846
# 07           778
# 08           735
# 09            20
# Name: GRADE , dtype: int64

# %%
mask = (cls['PROGRAM TYPE']=='GEN ED') & (cls['GRADE ']=='09-12')

# %%
cls = cls.loc[mask]

# %%
cls.head()
# Out:
#      CSD BOROUGH SCHOOL CODE                                    SCHOOL NAME  \
# 225    1       M        M292  Henry Street School for International Studies
# 226    1       M        M292  Henry Street School for International Studies
# 227    1       M        M292  Henry Street School for International Studies
# 228    1       M        M292  Henry Street School for International Studies
# 229    1       M        M292  Henry Street School for International Studies
#
#     GRADE  PROGRAM TYPE CORE SUBJECT (MS CORE and 9-12 ONLY)  \
# 225  09-12       GEN ED                              ENGLISH
# 226  09-12       GEN ED                              ENGLISH
# 227  09-12       GEN ED                              ENGLISH
# 228  09-12       GEN ED                              ENGLISH
# 229  09-12       GEN ED                                 MATH
#
#     CORE COURSE (MS CORE and 9-12 ONLY) SERVICE CATEGORY(K-9* ONLY)  \
# 225                           English 9                           -
# 226                          English 10                           -
# 227                          English 11                           -
# 228                          English 12                           -
# 229                  Integrated Algebra                           -
#
#      NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  \
# 225                               63.0                 3.0
# 226                               79.0                 3.0
# 227                               38.0                 2.0
# 228                               69.0                 3.0
# 229                               53.0                 3.0
#
#      AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# 225                21.0                    19.0                   25.0
# 226                26.3                    24.0                   31.0
# 227                19.0                    16.0                   22.0
# 228                23.0                    13.0                   30.0
# 229                17.7                    16.0                   21.0
#
#     DATA SOURCE  SCHOOLWIDE PUPIL-TEACHER RATIO     DBN
# 225       STARS                             NaN  01M292
# 226       STARS                             NaN  01M292
# 227       STARS                             NaN  01M292
# 228       STARS                             NaN  01M292
# 229       STARS                             NaN  01M292

# %%
cls['CORE SUBJECT (MS CORE and 9-12 ONLY)'].value_counts()  # 这个var可以忽略
# Out:
# ENGLISH           1977
# SCIENCE           1636
# SOCIAL STUDIES    1453
# MATH              1447
# Name: CORE SUBJECT (MS CORE and 9-12 ONLY), dtype: int64

# %%
for col in ['NUMBER OF STUDENTS / SEATS FILLED', 'NUMBER OF SECTIONS',
       'AVERAGE CLASS SIZE', 'SIZE OF SMALLEST CLASS', 'SIZE OF LARGEST CLASS']: 
    cls[col] = pd.to_numeric(cls.iloc[:, col], errors='coerce')

# %%
cls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6513 entries, 225 to 27608
# Data columns (total 17 columns):
# CSD                                     6513 non-null int64
# BOROUGH                                 6513 non-null object
# SCHOOL CODE                             6513 non-null object
# SCHOOL NAME                             6513 non-null object
# GRADE                                   6513 non-null object
# PROGRAM TYPE                            6513 non-null object
# CORE SUBJECT (MS CORE and 9-12 ONLY)    6513 non-null object
# CORE COURSE (MS CORE and 9-12 ONLY)     6513 non-null object
# SERVICE CATEGORY(K-9* ONLY)             6513 non-null object
# NUMBER OF STUDENTS / SEATS FILLED       6513 non-null float64
# NUMBER OF SECTIONS                      6513 non-null float64
# AVERAGE CLASS SIZE                      6513 non-null float64
# SIZE OF SMALLEST CLASS                  6513 non-null float64
# SIZE OF LARGEST CLASS                   6513 non-null float64
# DATA SOURCE                             6513 non-null object
# SCHOOLWIDE PUPIL-TEACHER RATIO          0 non-null float64
# DBN                                     6513 non-null object
# dtypes: float64(6), int64(1), object(10)
# memory usage: 915.9+ KB

# %%
cls = cls[['DBN', 'SCHOOL NAME','NUMBER OF STUDENTS / SEATS FILLED', 'NUMBER OF SECTIONS',
       'AVERAGE CLASS SIZE', 'SIZE OF SMALLEST CLASS', 'SIZE OF LARGEST CLASS']]

# %%
cls = cls.groupby(['DBN', 'SCHOOL NAME']).mean().reset_index()

# %%
cls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 7 columns):
# DBN                                  583 non-null object
# SCHOOL NAME                          583 non-null object
# NUMBER OF STUDENTS / SEATS FILLED    583 non-null float64
# NUMBER OF SECTIONS                   583 non-null float64
# AVERAGE CLASS SIZE                   583 non-null float64
# SIZE OF SMALLEST CLASS               583 non-null float64
# SIZE OF LARGEST CLASS                583 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 32.0+ KB

# %%
data['class_size'] = cls

# %% [markdown]
# ### cleaning 'demographics'

# %%
demo = data['demographics']
demo.head()
# Out:
#       DBN                       Name  schoolyear fl_percent  frl_percent  \
# 0  01M015  P.S. 015 ROBERTO CLEMENTE    20052006       89.4          NaN
# 1  01M015  P.S. 015 ROBERTO CLEMENTE    20062007       89.4          NaN
# 2  01M015  P.S. 015 ROBERTO CLEMENTE    20072008       89.4          NaN
# 3  01M015  P.S. 015 ROBERTO CLEMENTE    20082009       89.4          NaN
# 4  01M015  P.S. 015 ROBERTO CLEMENTE    20092010                    96.5
#
#    total_enrollment prek   k grade1 grade2    ...     black_num black_per  \
# 0               281   15  36     40     33    ...            74      26.3
# 1               243   15  29     39     38    ...            68      28.0
# 2               261   18  43     39     36    ...            77      29.5
# 3               252   17  37     44     32    ...            75      29.8
# 4               208   16  40     28     32    ...            67      32.2
#
#   hispanic_num hispanic_per white_num white_per male_num male_per female_num  \
# 0          189         67.3         5       1.8    158.0     56.2      123.0
# 1          153         63.0         4       1.6    140.0     57.6      103.0
# 2          157         60.2         7       2.7    143.0     54.8      118.0
# 3          149         59.1         7       2.8    149.0     59.1      103.0
# 4          118         56.7         6       2.9    124.0     59.6       84.0
#
#   female_per
# 0       43.8
# 1       42.4
# 2       45.2
# 3       40.9
# 4       40.4
#
# [5 rows x 38 columns]

# %%
demo.columns
# Out:
# Index(['DBN', 'Name', 'schoolyear', 'fl_percent', 'frl_percent',
#        'total_enrollment', 'prek', 'k', 'grade1', 'grade2', 'grade3', 'grade4',
#        'grade5', 'grade6', 'grade7', 'grade8', 'grade9', 'grade10', 'grade11',
#        'grade12', 'ell_num', 'ell_percent', 'sped_num', 'sped_percent',
#        'ctt_num', 'selfcontained_num', 'asian_num', 'asian_per', 'black_num',
#        'black_per', 'hispanic_num', 'hispanic_per', 'white_num', 'white_per',
#        'male_num', 'male_per', 'female_num', 'female_per'],
#       dtype='object')

# %% [markdown]
# 谷歌一下知道，美国的high school指的是grade9 - grade 12。([来源](http://www.go2travel.com.tw/PA/education/kiski/system.htm))

# %%
demo.loc[:, 'grade9':'grade12']
# Out:
#       grade9 grade10 grade11 grade12
# 0        NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN
# 3        NaN     NaN     NaN     NaN
# 4        NaN     NaN     NaN     NaN
# 5        NaN     NaN     NaN     NaN
# 6
# 7        NaN     NaN     NaN     NaN
# 8        NaN     NaN     NaN     NaN
# 9        NaN     NaN     NaN     NaN
# 10       NaN     NaN     NaN     NaN
# 11       NaN     NaN     NaN     NaN
# 12       NaN     NaN     NaN     NaN
# 13
# 14       NaN     NaN     NaN     NaN
# 15       NaN     NaN     NaN     NaN
# 16       NaN     NaN     NaN     NaN
# 17       NaN     NaN     NaN     NaN
# 18       NaN     NaN     NaN     NaN
# 19       NaN     NaN     NaN     NaN
# 20
# 21       NaN     NaN     NaN     NaN
# 22       NaN     NaN     NaN     NaN
# 23         1     NaN     NaN     NaN
# 24       NaN     NaN     NaN     NaN
# 25       NaN     NaN     NaN     NaN
# 26       NaN     NaN     NaN     NaN
# 27
# 28       NaN     NaN     NaN     NaN
# 29       NaN     NaN     NaN     NaN
# ...      ...     ...     ...     ...
# 10045    124     107     107      82
# 10046    118     119      91     106
# 10047    173     109      81     NaN
# 10048    178     137      74      69
# 10049    162     138      86      98
# 10050    148     130      85      98
# 10051    148     143      97      81
# 10052    125     141     107      98
# 10053     93     104     111      90
# 10054     45      23      26     NaN
# 10055     48      46      23      25
# 10056     44      49      42      21
# 10057     40      50      37      43
# 10058     34      37      36      49
# 10059     36      34      39      39
# 10060     37      34      34      35
# 10061    108     117      75     NaN
# 10062    145      99      86      87
# 10063    174     121      82      81
# 10064    176     144      80      89
# 10065    155     133     108      85
# 10066    136     109     111     144
# 10067    118     120     104     120
# 10068    NaN     357     NaN     NaN
# 10069    NaN     369     NaN       1
# 10070    NaN     355     NaN     NaN
# 10071    NaN     383     NaN     NaN
# 10072    NaN     395     NaN     NaN
# 10073    NaN     420     NaN     NaN
# 10074            382
#
# [10075 rows x 4 columns]

# %%
# 故技重施，把grade9 - grade12不全为空的行保留下来
mask = (demo.grade9.isnull()) & (demo.grade10.isnull()) & (demo.grade11.isnull()) & (demo.grade12.isnull())

demo = demo[~mask]

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4066 entries, 6 to 10074
# Data columns (total 38 columns):
# DBN                  4066 non-null object
# Name                 4066 non-null object
# schoolyear           4066 non-null int64
# fl_percent           2557 non-null object
# frl_percent          2420 non-null float64
# total_enrollment     4066 non-null int64
# prek                 1520 non-null object
# k                    1534 non-null object
# grade1               1541 non-null object
# grade2               1536 non-null object
# grade3               1536 non-null object
# grade4               1540 non-null object
# grade5               1547 non-null object
# grade6               1930 non-null object
# grade7               2001 non-null object
# grade8               2004 non-null object
# grade9               3974 non-null object
# grade10              3846 non-null object
# grade11              3674 non-null object
# grade12              3513 non-null object
# ell_num              3958 non-null float64
# ell_percent          4007 non-null float64
# sped_num             4001 non-null float64
# sped_percent         4066 non-null float64
# ctt_num              3540 non-null object
# selfcontained_num    3486 non-null object
# asian_num            4066 non-null int64
# asian_per            4066 non-null float64
# black_num            4066 non-null int64
# black_per            4066 non-null float64
# hispanic_num         4066 non-null int64
# hispanic_per         4066 non-null float64
# white_num            4066 non-null int64
# white_per            4066 non-null float64
# male_num             4042 non-null float64
# male_per             4066 non-null float64
# female_num           4053 non-null float64
# female_per           4066 non-null float64
# dtypes: float64(13), int64(6), object(19)
# memory usage: 1.2+ MB

# %%
demo.schoolyear.value_counts()
# Out:
# 20112012    1509
# 20102011     461
# 20092010     450
# 20082009     436
# 20072008     422
# 20062007     399
# 20052006     389
# Name: schoolyear, dtype: int64

# %%
demo = demo.loc[demo.schoolyear==20112012, :]

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1509 entries, 6 to 10074
# Data columns (total 38 columns):
# DBN                  1509 non-null object
# Name                 1509 non-null object
# schoolyear           1509 non-null int64
# fl_percent           0 non-null object
# frl_percent          1509 non-null float64
# total_enrollment     1509 non-null int64
# prek                 1509 non-null object
# k                    1509 non-null object
# grade1               1509 non-null object
# grade2               1509 non-null object
# grade3               1509 non-null object
# grade4               1509 non-null object
# grade5               1509 non-null object
# grade6               1509 non-null object
# grade7               1509 non-null object
# grade8               1509 non-null object
# grade9               1509 non-null object
# grade10              1509 non-null object
# grade11              1509 non-null object
# grade12              1509 non-null object
# ell_num              1509 non-null float64
# ell_percent          1509 non-null float64
# sped_num             1509 non-null float64
# sped_percent         1509 non-null float64
# ctt_num              1509 non-null object
# selfcontained_num    1509 non-null object
# asian_num            1509 non-null int64
# asian_per            1509 non-null float64
# black_num            1509 non-null int64
# black_per            1509 non-null float64
# hispanic_num         1509 non-null int64
# hispanic_per         1509 non-null float64
# white_num            1509 non-null int64
# white_per            1509 non-null float64
# male_num             1509 non-null float64
# male_per             1509 non-null float64
# female_num           1509 non-null float64
# female_per           1509 non-null float64
# dtypes: float64(13), int64(6), object(19)
# memory usage: 459.8+ KB

# %%
len(demo.DBN) - demo.DBN.nunique()
# Out:
# 0

# %%
cols = ['DBN', 'Name','asian_per', 'black_per', 
        'hispanic_per', 'white_per',
       'male_per',  'female_per'
        ]
demo = demo[cols]
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1509 entries, 6 to 10074
# Data columns (total 8 columns):
# DBN             1509 non-null object
# Name            1509 non-null object
# asian_per       1509 non-null float64
# black_per       1509 non-null float64
# hispanic_per    1509 non-null float64
# white_per       1509 non-null float64
# male_per        1509 non-null float64
# female_per      1509 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 106.1+ KB

# %%
data['demographics'] = demo

# %%
for key in data.keys():
    print(key)
    print(len(data[key]['DBN']) - len(data[key]['DBN'].unique()))
# Out:
# hs_directory
# 0
# survey
# 0
# math_test_results
# 0
# graduation
# 0
# sat_results
# 0
# ap_2010
# 0
# class_size
# 0
# demographics
# 0

# %% [markdown]
# Now we've condensed 'math_test_results', 'graduation', 'ap_2010', 'class_size' and 'demographcis' dataframe, each DBN in each dataframe is unique.

# %% [markdown]
# ## clean other data sets

# %% [markdown]
# We still have the following 3 datasets to look at and do some basic cleaning: 'hs_directory', 'survey', 'sat_results'.

# %% [markdown]
# ### clean 'hs_directory'

# %%
hs = data['hs_directory']
hs.head()
# Out:
#       dbn                                        school_name       boro  \
# 0  17K548                Brooklyn School for Music & Theatre   Brooklyn
# 1  09X543                   High School for Violin and Dance      Bronx
# 2  09X327        Comprehensive Model School Project M.S. 327      Bronx
# 3  02M280     Manhattan Early College School for Advertising  Manhattan
# 4  28Q680  Queens Gateway to Health Sciences Secondary Sc...     Queens
#
#   building_code    phone_number    fax_number  grade_span_min  grade_span_max  \
# 0          K440    718-230-6250  718-230-6262             9.0              12
# 1          X400    718-842-0687  718-589-9849             9.0              12
# 2          X240    718-294-8111  718-294-8109             6.0              12
# 3          M520  718-935-3477             NaN             9.0              10
# 4          Q695    718-969-3155  718-969-3552             6.0              12
#
#   expgrade_span_min  expgrade_span_max   ...    \
# 0               NaN                NaN   ...
# 1               NaN                NaN   ...
# 2               NaN                NaN   ...
# 3                 9               14.0   ...
# 4               NaN                NaN   ...
#
#                                           priority03  \
# 0                                                NaN
# 1                Then to Bronx students or residents
# 2  Then to New York City residents who attend an ...
# 3          Then to Manhattan students or residents
# 4               Then to Queens students or residents
#
#                             priority04                       priority05  \
# 0                                  NaN                              NaN
# 1      Then to New York City residents                              NaN
# 2  Then to Bronx students or residents  Then to New York City residents
# 3      Then to New York City residents                              NaN
# 4      Then to New York City residents                              NaN
#
#   priority06 priority07  priority08 priority09  priority10  \
# 0        NaN        NaN         NaN        NaN         NaN
# 1        NaN        NaN         NaN        NaN         NaN
# 2        NaN        NaN         NaN        NaN         NaN
# 3        NaN        NaN         NaN        NaN         NaN
# 4        NaN        NaN         NaN        NaN         NaN
#
#                                           Location 1     DBN
# 0  883 Classon Avenue\nBrooklyn, NY 11225\n(40.67...  17K548
# 1  1110 Boston Road\nBronx, NY 10456\n(40.8276026...  09X543
# 2  1501 Jerome Avenue\nBronx, NY 10452\n(40.84241...  09X327
# 3  411 Pearl Street\nNew York, NY 10038\n(40.7106...  02M280
# 4  160-20 Goethals Avenue\nJamaica, NY 11432\n(40...  28Q680
#
# [5 rows x 59 columns]

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 59 columns):
# dbn                                 435 non-null object
# school_name                         435 non-null object
# boro                                435 non-null object
# building_code                       435 non-null object
# phone_number                        435 non-null object
# fax_number                          423 non-null object
# grade_span_min                      435 non-null object
# grade_span_max                      435 non-null int64
# expgrade_span_min                   33 non-null object
# expgrade_span_max                   33 non-null float64
# bus                                 434 non-null object
# subway                              358 non-null object
# primary_address_line_1              435 non-null object
# city                                435 non-null object
# state_code                          435 non-null object
# zip                                 435 non-null int64
# website                             430 non-null object
# total_students                      426 non-null float64
# campus_name                         217 non-null object
# school_type                         104 non-null object
# overview_paragraph                  434 non-null object
# program_highlights                  434 non-null object
# language_classes                    412 non-null object
# advancedplacement_courses           340 non-null object
# online_ap_courses                   64 non-null object
# online_language_courses             73 non-null object
# extracurricular_activities          435 non-null object
# psal_sports_boys                    380 non-null object
# psal_sports_girls                   373 non-null object
# psal_sports_coed                    147 non-null object
# school_sports                       297 non-null object
# partner_cbo                         354 non-null object
# partner_hospital                    196 non-null object
# partner_highered                    378 non-null object
# partner_cultural                    305 non-null object
# partner_nonprofit                   298 non-null object
# partner_corporate                   198 non-null object
# partner_financial                   72 non-null object
# partner_other                       188 non-null object
# addtl_info1                         354 non-null object
# addtl_info2                         229 non-null object
# start_time                          431 non-null object
# end_time                            431 non-null object
# se_services                         435 non-null object
# ell_programs                        435 non-null object
# school_accessibility_description    435 non-null object
# number_programs                     435 non-null int64
# priority01                          435 non-null object
# priority02                          352 non-null object
# priority03                          243 non-null object
# priority04                          177 non-null object
# priority05                          39 non-null object
# priority06                          17 non-null object
# priority07                          4 non-null object
# priority08                          1 non-null object
# priority09                          1 non-null object
# priority10                          1 non-null object
# Location 1                          435 non-null object
# DBN                                 435 non-null object
# dtypes: float64(2), int64(3), object(54)
# memory usage: 200.6+ KB

# %%
hs.grade_span_min = pd.to_numeric(hs.grade_span_min, errors='coerce')

# %%
hs = hs.loc[(hs.grade_span_min <= 9)&(hs.grade_span_max >= 9), :]
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 432 entries, 0 to 434
# Data columns (total 59 columns):
# dbn                                 432 non-null object
# school_name                         432 non-null object
# boro                                432 non-null object
# building_code                       432 non-null object
# phone_number                        432 non-null object
# fax_number                          420 non-null object
# grade_span_min                      432 non-null float64
# grade_span_max                      432 non-null int64
# expgrade_span_min                   32 non-null object
# expgrade_span_max                   32 non-null float64
# bus                                 431 non-null object
# subway                              356 non-null object
# primary_address_line_1              432 non-null object
# city                                432 non-null object
# state_code                          432 non-null object
# zip                                 432 non-null int64
# website                             427 non-null object
# total_students                      423 non-null float64
# campus_name                         216 non-null object
# school_type                         104 non-null object
# overview_paragraph                  431 non-null object
# program_highlights                  431 non-null object
# language_classes                    409 non-null object
# advancedplacement_courses           337 non-null object
# online_ap_courses                   64 non-null object
# online_language_courses             73 non-null object
# extracurricular_activities          432 non-null object
# psal_sports_boys                    378 non-null object
# psal_sports_girls                   371 non-null object
# psal_sports_coed                    147 non-null object
# school_sports                       294 non-null object
# partner_cbo                         351 non-null object
# partner_hospital                    196 non-null object
# partner_highered                    376 non-null object
# partner_cultural                    303 non-null object
# partner_nonprofit                   296 non-null object
# partner_corporate                   197 non-null object
# partner_financial                   72 non-null object
# partner_other                       188 non-null object
# addtl_info1                         352 non-null object
# addtl_info2                         229 non-null object
# start_time                          428 non-null object
# end_time                            428 non-null object
# se_services                         432 non-null object
# ell_programs                        432 non-null object
# school_accessibility_description    432 non-null object
# number_programs                     432 non-null int64
# priority01                          432 non-null object
# priority02                          350 non-null object
# priority03                          243 non-null object
# priority04                          177 non-null object
# priority05                          39 non-null object
# priority06                          17 non-null object
# priority07                          4 non-null object
# priority08                          1 non-null object
# priority09                          1 non-null object
# priority10                          1 non-null object
# Location 1                          432 non-null object
# DBN                                 432 non-null object
# dtypes: float64(3), int64(3), object(53)
# memory usage: 202.5+ KB

# %%
cols = ['school_type', 'advancedplacement_courses', 'online_ap_courses', 
        'extracurricular_activities', 'school_sports', 'partner_cbo', 
        'partner_hospital', 'partner_highered', 'partner_cultural', 
        'partner_nonprofit', 'partner_corporate', 'partner_financial', 
        'partner_other', 'se_services', 'ell_programs', 'number_programs']

# %%
for col in cols:
    print('--' * 20)
    print(col + ':\n')
    print(hs[col].value_counts().head(2))
# Out:
# ----------------------------------------
# school_type:
#
# CTE School           36
# Consortium School    17
# Name: school_type, dtype: int64
# ----------------------------------------
# advancedplacement_courses:
#
# English Literature and Composition, United States History    10
# English Literature and Composition                            8
# Name: advancedplacement_courses, dtype: int64
# ----------------------------------------
# online_ap_courses:
#
# Biology                         3
# Spanish Language and Culture    3
# Name: online_ap_courses, dtype: int64
# ----------------------------------------
# extracurricular_activities:
#
# After-school Tutoring, Art, Fine and Visual Arts (Ceramics, Drawing, Painting, Sculpture), Art History, Cheerleading, Vocal Music (Concert Choir, Chorus), Fine and Performing Arts (Dance, Drama), Journalism, Instrumental Music, Marching Band, Math, Mentor, Mock Trial, Music, National Honor Society, Photography, Poetry, SAT Prep, Saturday Academy, Science, Step Team, Student Government, Table Tennis, Tennis, Travel    1
# Access to LaGuardia Community College facilities, Advocacy Lab, After-school Tutoring, Art, Chess, Chinese, Chorus, Computer, Environmental, Forensic Science, Global Kids, Internship/Community Service, Latino Club, Math, Movie, Music, Saturday Literacy/Math, South Asian Club, Student Government, Students in Free Enterprise (SIFE), The Girls Project, Theater, Yearbook, Young Citizens Center                             1
# Name: extracurricular_activities, dtype: int64
# ----------------------------------------
# school_sports:
#
# Cheerleading         11
# Intramural Sports     4
# Name: school_sports, dtype: int64
# ----------------------------------------
# partner_cbo:
#
# Children's Aid Society    3
# South Bronx Churches      2
# Name: partner_cbo, dtype: int64
# ----------------------------------------
# partner_hospital:
#
# Montefiore Medical Center    6
# Coney Island Hospital        3
# Name: partner_hospital, dtype: int64
# ----------------------------------------
# partner_highered:
#
# LaGuardia Community College    5
# Lehman College                 5
# Name: partner_highered, dtype: int64
# ----------------------------------------
# partner_cultural:
#
# Jamaica Center for Arts and Learning    2
# Lincoln Center Institute                2
# Name: partner_cultural, dtype: int64
# ----------------------------------------
# partner_nonprofit:
#
# New Visions for Public Schools    6
# The Urban Assembly                5
# Name: partner_nonprofit, dtype: int64
# ----------------------------------------
# partner_corporate:
#
# Con Edison       2
# Merrill Lynch    2
# Name: partner_corporate, dtype: int64
# ----------------------------------------
# partner_financial:
#
# JP Morgan Chase    4
# Citibank           2
# Name: partner_financial, dtype: int64
# ----------------------------------------
# partner_other:
#
# Consulate General of France in New York    2
# Institute for Student Achievement          2
# Name: partner_other, dtype: int64
# ----------------------------------------
# se_services:
#
# This school will provide students with disabilities the supports and services indicated on their IEPs.    432
# Name: se_services, dtype: int64
# ----------------------------------------
# ell_programs:
#
# ESL                                             389
# ESL; Transitional Bilingual Program: Spanish     23
# Name: ell_programs, dtype: int64
# ----------------------------------------
# number_programs:
#
# 1    319
# 2     46
# Name: number_programs, dtype: int64

# %%
try:
    for col in cols[1:-1]:
        hs.loc[:, col] = hs[col].fillna('').str.split(',')
        hs.loc[:, col] = hs[col].apply(lambda x: 0 if x == [''] else len(x))
except:
    print(col)
# Out:
# /Users/EzraYang/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for col in cols:
    print('--' * 20)
    print(col + ':\n')
    print(hs[col].value_counts().head(2))
# Out:
# ----------------------------------------
# school_type:
#
# CTE School           36
# Consortium School    17
# Name: school_type, dtype: int64
# ----------------------------------------
# advancedplacement_courses:
#
# 0    95
# 3    46
# Name: advancedplacement_courses, dtype: int64
# ----------------------------------------
# online_ap_courses:
#
# 0    368
# 2     17
# Name: online_ap_courses, dtype: int64
# ----------------------------------------
# extracurricular_activities:
#
# 12    28
# 13    24
# Name: extracurricular_activities, dtype: int64
# ----------------------------------------
# school_sports:
#
# 0    138
# 1     78
# Name: school_sports, dtype: int64
# ----------------------------------------
# partner_cbo:
#
# 1    90
# 0    81
# Name: partner_cbo, dtype: int64
# ----------------------------------------
# partner_hospital:
#
# 0    236
# 1    125
# Name: partner_hospital, dtype: int64
# ----------------------------------------
# partner_highered:
#
# 1    90
# 2    64
# Name: partner_highered, dtype: int64
# ----------------------------------------
# partner_cultural:
#
# 0    129
# 1     75
# Name: partner_cultural, dtype: int64
# ----------------------------------------
# partner_nonprofit:
#
# 0    136
# 1    101
# Name: partner_nonprofit, dtype: int64
# ----------------------------------------
# partner_corporate:
#
# 0    235
# 1     81
# Name: partner_corporate, dtype: int64
# ----------------------------------------
# partner_financial:
#
# 0    360
# 1     46
# Name: partner_financial, dtype: int64
# ----------------------------------------
# partner_other:
#
# 0    244
# 1     82
# Name: partner_other, dtype: int64
# ----------------------------------------
# se_services:
#
# 1    432
# Name: se_services, dtype: int64
# ----------------------------------------
# ell_programs:
#
# 1    422
# 2      9
# Name: ell_programs, dtype: int64
# ----------------------------------------
# number_programs:
#
# 1    319
# 2     46
# Name: number_programs, dtype: int64

# %% [markdown]
# Now they are all in int type.

# %%
hs = hs[cols]

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 432 entries, 0 to 434
# Data columns (total 19 columns):
# school_type                   104 non-null object
# advancedplacement_courses     432 non-null int64
# online_ap_courses             432 non-null int64
# extracurricular_activities    432 non-null int64
# school_sports                 432 non-null int64
# partner_cbo                   432 non-null int64
# partner_hospital              432 non-null int64
# partner_highered              432 non-null int64
# partner_cultural              432 non-null int64
# partner_nonprofit             432 non-null int64
# partner_corporate             432 non-null int64
# partner_financial             432 non-null int64
# partner_other                 432 non-null int64
# se_services                   432 non-null int64
# ell_programs                  432 non-null int64
# number_programs               432 non-null int64
# Location 1                    432 non-null object
# DBN                           432 non-null object
# school_name                   432 non-null object
# dtypes: int64(15), object(4)
# memory usage: 67.5+ KB

# %%
# adding lat and lon columns
hs['lat'] = hs['Location 1'].apply(lambda x: x.split("\n")[-1].replace("(", "").replace(")", "").split(", ")[0])
hs['lon'] = hs['Location 1'].apply(lambda x: x.split("\n")[-1].replace("(", "").replace(")", "").split(", ")[1])

for c in ['lat', 'lon']:
    hs[c] = pd.to_numeric(hs[c])
# Out:
# /Users/EzraYang/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/EzraYang/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/EzraYang/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['hs_directory'] = hs

# %% [markdown]
# ### clean 'survey' dataset

# %%
sv = data['survey']
sv.head()
# Out:
#       DBN  rr_s  rr_t  rr_p    N_s   N_t    N_p  saf_p_11  com_p_11  eng_p_11  \
# 0  01M015   NaN    88    60    NaN  22.0   90.0       8.5       7.6       7.5
# 1  01M019   NaN   100    60    NaN  34.0  161.0       8.4       7.6       7.6
# 2  01M020   NaN    88    73    NaN  42.0  367.0       8.9       8.3       8.3
# 3  01M034  89.0    73    50  145.0  29.0  151.0       8.8       8.2       8.0
# 4  01M063   NaN   100    60    NaN  23.0   90.0       8.7       7.9       8.1
#
#       ...      eng_t_10  aca_t_11  saf_s_11  com_s_11  eng_s_11  aca_s_11  \
# 0     ...           NaN       7.9       NaN       NaN       NaN       NaN
# 1     ...           NaN       9.1       NaN       NaN       NaN       NaN
# 2     ...           NaN       7.5       NaN       NaN       NaN       NaN
# 3     ...           NaN       7.8       6.2       5.9       6.5       7.4
# 4     ...           NaN       8.1       NaN       NaN       NaN       NaN
#
#    saf_tot_11  com_tot_11  eng_tot_11  aca_tot_11
# 0         8.0         7.7         7.5         7.9
# 1         8.5         8.1         8.2         8.4
# 2         8.2         7.3         7.5         8.0
# 3         7.3         6.7         7.1         7.9
# 4         8.5         7.6         7.9         8.0
#
# [5 rows x 23 columns]

# %%
sv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1702 entries, 0 to 55
# Data columns (total 23 columns):
# DBN           1702 non-null object
# rr_s          1041 non-null float64
# rr_t          1702 non-null int64
# rr_p          1702 non-null int64
# N_s           1036 non-null float64
# N_t           1700 non-null float64
# N_p           1696 non-null float64
# saf_p_11      1696 non-null float64
# com_p_11      1696 non-null float64
# eng_p_11      1696 non-null float64
# aca_p_11      1696 non-null float64
# saf_t_11      1700 non-null float64
# com_t_11      1700 non-null float64
# eng_t_10      0 non-null float64
# aca_t_11      1700 non-null float64
# saf_s_11      1036 non-null float64
# com_s_11      1036 non-null float64
# eng_s_11      1036 non-null float64
# aca_s_11      1036 non-null float64
# saf_tot_11    1702 non-null float64
# com_tot_11    1702 non-null float64
# eng_tot_11    1702 non-null float64
# aca_tot_11    1702 non-null float64
# dtypes: float64(20), int64(2), object(1)
# memory usage: 319.1+ KB

# %%
# it's clean enough

# %% [markdown]
# ### clean 'sat_results'

# %%
sat = data['sat_results']
sat.head()
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
# 2                     70                             377                 402
# 3                      7                             414                 401
# 4                     44                             390                 433
#
#   SAT Writing Avg. Score
# 0                    363
# 1                    366
# 2                    370
# 3                    359
# 4                    384

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 6 columns):
# DBN                                478 non-null object
# SCHOOL NAME                        478 non-null object
# Num of SAT Test Takers             478 non-null object
# SAT Critical Reading Avg. Score    478 non-null object
# SAT Math Avg. Score                478 non-null object
# SAT Writing Avg. Score             478 non-null object
# dtypes: object(6)
# memory usage: 22.5+ KB

# %%
sat.columns
# Out:
# Index(['DBN', 'SCHOOL NAME', 'Num of SAT Test Takers',
#        'SAT Critical Reading Avg. Score', 'SAT Math Avg. Score',
#        'SAT Writing Avg. Score'],
#       dtype='object')

# %%
cols = ['Num of SAT Test Takers',
       'SAT Critical Reading Avg. Score', 'SAT Math Avg. Score',
       'SAT Writing Avg. Score']

# %%
for col in cols:
    sat[col] = pd.to_numeric(sat.loc[:, col], errors='coerce')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 6 columns):
# DBN                                478 non-null object
# SCHOOL NAME                        478 non-null object
# Num of SAT Test Takers             421 non-null float64
# SAT Critical Reading Avg. Score    421 non-null float64
# SAT Math Avg. Score                421 non-null float64
# SAT Writing Avg. Score             421 non-null float64
# dtypes: float64(4), object(2)
# memory usage: 22.5+ KB

# %%
sat['sat_score'] = sat[cols[1]] + sat[cols[2]] + sat[cols[3]]

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 7 columns):
# DBN                                478 non-null object
# SCHOOL NAME                        478 non-null object
# Num of SAT Test Takers             421 non-null float64
# SAT Critical Reading Avg. Score    421 non-null float64
# SAT Math Avg. Score                421 non-null float64
# SAT Writing Avg. Score             421 non-null float64
# sat_score                          421 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 26.2+ KB

# %%
data['sat_results'] = sat

# %% [markdown]
# Now we have looked into each of the datasets in the 'data' dictionary, we've made sure each row represents a unique school, extract useful columns, and convert data type wherever necessary.
# Next we can combine them into one single dataframe.

# %% [markdown]
# ## combining the dataset

# %%
data.keys()
# Out:
# dict_keys(['hs_directory', 'survey', 'math_test_results', 'graduation', 'sat_results', 'ap_2010', 'class_size', 'demographics'])

# %%
full = data['sat_results']

# %%
for key in ['hs_directory', 'survey', 'math_test_results', 'graduation',
            'ap_2010', 'class_size', 'demographics']:
    full = full.merge(data[key], on='DBN', how='left')

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 0 to 477
# Data columns (total 80 columns):
# DBN                                     478 non-null object
# SCHOOL NAME                             478 non-null object
# Num of SAT Test Takers                  421 non-null float64
# SAT Critical Reading Avg. Score         421 non-null float64
# SAT Math Avg. Score                     421 non-null float64
# SAT Writing Avg. Score                  421 non-null float64
# sat_score                               421 non-null float64
# school_type                             72 non-null object
# advancedplacement_courses               367 non-null float64
# online_ap_courses                       367 non-null float64
# extracurricular_activities              367 non-null float64
# school_sports                           367 non-null float64
# partner_cbo                             367 non-null float64
# partner_hospital                        367 non-null float64
# partner_highered                        367 non-null float64
# partner_cultural                        367 non-null float64
# partner_nonprofit                       367 non-null float64
# partner_corporate                       367 non-null float64
# partner_financial                       367 non-null float64
# partner_other                           367 non-null float64
# se_services                             367 non-null float64
# ell_programs                            367 non-null float64
# number_programs                         367 non-null float64
# Location 1                              367 non-null object
# school_name                             367 non-null object
# lat                                     367 non-null float64
# lon                                     367 non-null float64
# rr_s                                    470 non-null float64
# rr_t                                    470 non-null float64
# rr_p                                    470 non-null float64
# N_s                                     466 non-null float64
# N_t                                     470 non-null float64
# N_p                                     469 non-null float64
# saf_p_11                                469 non-null float64
# com_p_11                                469 non-null float64
# eng_p_11                                469 non-null float64
# aca_p_11                                469 non-null float64
# saf_t_11                                470 non-null float64
# com_t_11                                470 non-null float64
# eng_t_10                                0 non-null float64
# aca_t_11                                470 non-null float64
# saf_s_11                                466 non-null float64
# com_s_11                                466 non-null float64
# eng_s_11                                466 non-null float64
# aca_s_11                                466 non-null float64
# saf_tot_11                              470 non-null float64
# com_tot_11                              470 non-null float64
# eng_tot_11                              470 non-null float64
# aca_tot_11                              470 non-null float64
# Number Tested                           85 non-null float64
# Mean Scale Score                        84 non-null float64
# Level 1 %                               84 non-null float64
# Level 2 %                               84 non-null float64
# Level 3 %                               84 non-null float64
# Level 4 %                               84 non-null float64
# Level 3+4 %                             84 non-null float64
# School Name                             368 non-null object
# Total Grads - % of cohort               368 non-null float64
# Total Regents - % of cohort             368 non-null float64
# Advanced Regents - % of cohort          368 non-null float64
# Local - % of cohort                     368 non-null float64
# Still Enrolled - % of cohort            368 non-null float64
# Dropped Out - % of cohort               368 non-null float64
# SchoolName                              232 non-null object
# AP Test Takers                          232 non-null float64
# Total Exams Taken                       232 non-null float64
# Number of Exams with scores 3 4 or 5    151 non-null float64
# SCHOOL NAME_clas                        434 non-null object
# NUMBER OF STUDENTS / SEATS FILLED       434 non-null float64
# NUMBER OF SECTIONS                      434 non-null float64
# AVERAGE CLASS SIZE                      434 non-null float64
# SIZE OF SMALLEST CLASS                  434 non-null float64
# SIZE OF LARGEST CLASS                   434 non-null float64
# Name                                    450 non-null object
# asian_per                               450 non-null float64
# black_per                               450 non-null float64
# hispanic_per                            450 non-null float64
# white_per                               450 non-null float64
# male_per                                450 non-null float64
# female_per                              450 non-null float64
# dtypes: float64(71), object(9)
# memory usage: 302.5+ KB

# %%
full.shape
# Out:
# (478, 80)

# %%
# add a column to indicate school district
full["school_dist"] = full["DBN"].apply(lambda x: x[:2])

# %% [markdown]
# Finally, we’ll need to fill in any missing values in full with the median of the column, so we can compute correlations:

# %%
full = full.fillna(full.median())

# %% [markdown]
# ## computing correlations

# %%
full.corr().shape
# Out:
# (71, 71)

# %%
r = full.corr()['sat_score'].dropna().round(decimals=2)

# %%
strong = r[abs(r) >= 0.7]
upper_med = r[(0.7> abs(r)) & (abs(r)>= 0.5)]
lower_med = r[(0.5 > abs(r)) & (abs(r)>= 0.3)]
weak = r[0.3 > abs(r) ]

# %%
for gr in [strong, upper_med, lower_med, weak]:
    print(len(gr))
# Out:
# 5
# 7
# 14
# 43

# %%
strong
# Out:
# SAT Critical Reading Avg. Score    0.97
# SAT Math Avg. Score                0.95
# SAT Writing Avg. Score             0.98
# sat_score                          1.00
# Advanced Regents - % of cohort     0.77
# Name: sat_score, dtype: float64

# %%
upper_med
# Out:
# advancedplacement_courses               0.52
# Total Regents - % of cohort             0.60
# AP Test Takers                          0.55
# Total Exams Taken                       0.54
# Number of Exams with scores 3 4 or 5    0.53
# asian_per                               0.53
# white_per                               0.63
# Name: sat_score, dtype: float64

# %%
lower_med
# Out:
# Num of SAT Test Takers               0.49
# extracurricular_activities           0.41
# N_s                                  0.43
# N_t                                  0.30
# N_p                                  0.44
# Total Grads - % of cohort            0.46
# Local - % of cohort                 -0.40
# Still Enrolled - % of cohort        -0.37
# Dropped Out - % of cohort           -0.43
# NUMBER OF STUDENTS / SEATS FILLED    0.39
# NUMBER OF SECTIONS                   0.36
# AVERAGE CLASS SIZE                   0.37
# SIZE OF LARGEST CLASS                0.31
# hispanic_per                        -0.35
# Name: sat_score, dtype: float64

# %%
weak
# Out:
# online_ap_courses        -0.04
# school_sports            -0.04
# partner_cbo              -0.07
# partner_hospital         -0.02
# partner_highered          0.18
# partner_cultural          0.14
# partner_nonprofit        -0.01
# partner_corporate         0.06
# partner_financial         0.08
# partner_other             0.03
# ell_programs              0.04
# number_programs           0.16
# lat                      -0.11
# lon                      -0.11
# rr_s                      0.27
# rr_t                      0.00
# rr_p                      0.10
# saf_p_11                  0.09
# com_p_11                 -0.09
# eng_p_11                  0.02
# aca_p_11                  0.02
# saf_t_11                  0.27
# com_t_11                  0.08
# aca_t_11                  0.12
# saf_s_11                  0.23
# com_s_11                  0.13
# eng_s_11                  0.13
# aca_s_11                  0.25
# saf_tot_11                0.24
# com_tot_11                0.07
# eng_tot_11                0.07
# aca_tot_11                0.15
# Number Tested             0.09
# Mean Scale Score          0.24
# Level 1 %                -0.15
# Level 2 %                -0.27
# Level 3 %                 0.12
# Level 4 %                 0.27
# Level 3+4 %               0.26
# SIZE OF SMALLEST CLASS    0.25
# black_per                -0.29
# male_per                 -0.09
# female_per                0.09
# Name: sat_score, dtype: float64

# %% [markdown]
# 后记，数据格式转换这一步其实应该在condensing datasets时顺手做掉，
# 因为到现在已经合并了df了，full有太多栏，到时候报错比较难发现到底哪里出错。
